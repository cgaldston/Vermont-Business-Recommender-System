# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from collections import defaultdict
from sklearn import linear_model
import json

# %%
rating_data = pd.read_csv("ratings_export.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 rating_data = pd.read_csv("ratings_export.csv")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ratings_export.csv'

# %%
rating_data
# Out:
#                                _id             movie_id  rating_val  \
# 0         5fc57c5d6758f6963451a07f           feast-2014           7
# 1         5fc57c5d6758f6963451a063          loving-2016           7
# 2         5fc57c5d6758f6963451a0ef     scripted-content           7
# 3         5fc57c5d6758f6963451a060           the-future           4
# 4         5fc57c5c6758f69634519398                 mank           5
# ...                            ...                  ...         ...
# 11078162  6239f4f1a936b95600b3d798              alien-3           6
# 11078163  6239f4f1a936b95600b3d799  battleship-potemkin           7
# 11078164  6239f4f1a936b95600b3d79e               pusher           6
# 11078165  6239f4f1a936b95600b3d7a1    wild-strawberries           7
# 11078166  6239f4f1a936b95600b3d7a2               x-2022           5
#
#              user_id
# 0         deathproof
# 1         deathproof
# 2         deathproof
# 3         deathproof
# 4         deathproof
# ...              ...
# 11078162    turnitip
# 11078163    turnitip
# 11078164    turnitip
# 11078165    turnitip
# 11078166    turnitip
#
# [11078167 rows x 4 columns]

# %% [markdown]
# We have 11078167 reviews.

# %%
movie_data = pd.read_csv("movie_data.csv", on_bad_lines='skip')

# %%
movie_data = movie_data.drop(["genres", "image_url", "imdb_id", "spoken_languages", "tmdb_id", "tmdb_link", "vote_average", "vote_count", "imdb_link"], axis = 1)

# %%
movie_data
# Out:
#                              _id                          movie_id  \
# 0       5fc85f606758f69634496fd3                   football-freaks
# 1       5fc85ff26758f696344ace0c                    aftermath-1960
# 2       5fc85f606758f69634496fcd           where-chimneys-are-seen
# 3       5fc85f606758f69634496fd1            the-musicians-daughter
# 4       5fc85f606758f69634496fd4              50-years-of-fabulous
# ...                          ...                               ...
# 285958  6239f32da936b95600b301d8  the-western-world-of-sailor-moon
# 285959  6239f32da936b95600b301e8                        shadowplay
# 285960  6239f32da936b95600b301f2                   only-always-you
# 285961  6239f32da936b95600b301fb   one-night-stand-ellen-degeneres
# 285962  6239f32da936b95600b30204              the-french-democracy
#
#                     movie_title original_language  \
# 0               Football Freaks                en
# 1                     Aftermath                en
# 2       Where Chimneys Are Seen                ja
# 3       The Musician's Daughter                en
# 4          50 Years of Fabulous                en
# ...                         ...               ...
# 285958                      NaN               NaN
# 285959                      NaN               NaN
# 285960                      NaN               NaN
# 285961                      NaN               NaN
# 285962                      NaN               NaN
#
#                                                  overview  popularity  \
# 0       Football crazy, football mad. Don’t watch this...       0.600
# 1       Aftermath was the pilot for an unsold TV serie...       0.600
# 2       Gosho’s most celebrated film both in Japan and...       1.568
# 3       Carl Wagner's good wife was dying. His heart b...       0.600
# 4       50 Years of Fabulous recounts the rich history...       0.600
# ...                                                   ...         ...
# 285958                                                NaN         NaN
# 285959                                                NaN         NaN
# 285960                                                NaN         NaN
# 285961                                                NaN         NaN
# 285962                                                NaN         NaN
#
#                 production_countries release_date  runtime  year_released
# 0                 ["United Kingdom"]   1971-12-05      0.0         1971.0
# 1                                 []   1960-04-17     22.0         1960.0
# 2                          ["Japan"]   1953-03-05    108.0         1953.0
# 3       ["United States of America"]   1911-12-12     15.0         1911.0
# 4                                 []   2018-05-17     75.0         2018.0
# ...                              ...          ...      ...            ...
# 285958                           NaN          NaN      NaN            NaN
# 285959                           NaN          NaN      NaN            NaN
# 285960                           NaN          NaN      NaN            NaN
# 285961                           NaN          NaN      NaN            NaN
# 285962                           NaN          NaN      NaN            NaN
#
# [285963 rows x 10 columns]

# %%
user_data = pd.read_csv("users_export.csv")

# %%
user_data
# Out:
#                            _id        display_name  num_ratings_pages  \
# 0     5fc4172ec6cd28ebd99dd0e2                Lucy               32.0
# 1     5fc4172ec6cd28ebd99dd0ea         Matt Singer               52.0
# 2     5fc4172ec6cd28ebd99dd0ed          Sean Baker               21.0
# 3     5fc4172ec6cd28ebd99dd0ee                iana               37.0
# 4     5fc419171ebf67b9fbe48615               Lizzy               57.0
# ...                        ...                 ...                ...
# 8134  6239b430a936b956009c993c  Máté Turi-Mészáros                NaN
# 8135  6239cbf7a936b95600a2d24c                Finn                NaN
# 8136  6239d254a936b95600a4472f              Daniel                NaN
# 8137  6239df37a936b95600aa7aa5      ButterflyFilms                NaN
# 8138  6239e55ba936b95600ae2012                 Flo                NaN
#
#       num_reviews         username
# 0            1650       deathproof
# 1            1915       superpulse
# 2            1283          lilfilm
# 3            1177       ianamurray
# 4            1810  punchdrunklizzy
# ...           ...              ...
# 8134          237      mateazember
# 8135          297         finnvor1
# 8136         1231           daniel
# 8137          800   butterflyfilms
# 8138         1901      poellnerson
#
# [8139 rows x 5 columns]

# %%
ratings_movies = pd.merge(rating_data, movie_data, on='movie_id', how='left')

# %%
ratings_movies = ratings_movies.drop(["_id_y", "imdb_link"], axis=1)

# %%
ratings_movies
# Out:
#                              _id_x             movie_id  rating_val  \
# 0         5fc57c5d6758f6963451a07f           feast-2014           7
# 1         5fc57c5d6758f6963451a063          loving-2016           7
# 2         5fc57c5d6758f6963451a0ef     scripted-content           7
# 3         5fc57c5d6758f6963451a060           the-future           4
# 4         5fc57c5c6758f69634519398                 mank           5
# ...                            ...                  ...         ...
# 11080238  6239f4f1a936b95600b3d798              alien-3           6
# 11080239  6239f4f1a936b95600b3d799  battleship-potemkin           7
# 11080240  6239f4f1a936b95600b3d79e               pusher           6
# 11080241  6239f4f1a936b95600b3d7a1    wild-strawberries           7
# 11080242  6239f4f1a936b95600b3d7a2               x-2022           5
#
#              user_id          movie_title original_language  \
# 0         deathproof                Feast                en
# 1         deathproof               Loving                en
# 2         deathproof     Scripted Content                en
# 3         deathproof           The Future                en
# 4         deathproof                 Mank                en
# ...              ...                  ...               ...
# 11080238    turnitip               Alien³                en
# 11080239    turnitip  Battleship Potemkin                ru
# 11080240    turnitip               Pusher                da
# 11080241    turnitip    Wild Strawberries                sv
# 11080242    turnitip                    X                en
#
#                                                    overview  popularity  \
# 0         This Oscar-winning animated short film tells t...       9.260
# 1         The story of Richard and Mildred Loving, an in...      18.024
# 2         A very short film for Vogue starring Jessica C...       1.400
# 3         When a couple decides to adopt a stray cat the...       5.208
# 4         1930s Hollywood is reevaluated through the eye...      16.331
# ...                                                     ...         ...
# 11080238  After escaping with Newt and Hicks from the al...      22.524
# 11080239  A dramatized account of a great Russian naval ...       8.771
# 11080240  A drug pusher grows increasingly desperate aft...       6.615
# 11080241  Crotchety retired doctor Isak Borg travels fro...      13.574
# 11080242  In 1979, a group of young filmmakers set out t...      99.026
#
#                                        production_countries release_date  \
# 0                              ["United States of America"]   2014-10-25
# 1             ["United Kingdom","United States of America"]   2016-11-04
# 2                              ["United States of America"]   2014-06-01
# 3         ["Germany","United States of America","France"...   2011-07-29
# 4                              ["United States of America"]   2020-11-13
# ...                                                     ...          ...
# 11080238      ["United Kingdom","United States of America"]   1992-05-22
# 11080239                                   ["Soviet Union"]   1925-12-24
# 11080240                                        ["Denmark"]   1996-08-30
# 11080241                                         ["Sweden"]   1957-12-26
# 11080242                       ["United States of America"]   2022-03-17
#
#           runtime  year_released
# 0             6.0         2014.0
# 1           123.0         2016.0
# 2             2.0         2014.0
# 3            91.0         2011.0
# 4           132.0         2020.0
# ...           ...            ...
# 11080238    114.0         1992.0
# 11080239     75.0         1925.0
# 11080240    105.0         1996.0
# 11080241     91.0         1957.0
# 11080242    106.0         2022.0
#
# [11080243 rows x 12 columns]

# %%
# Group by movie_id and count the number of reviews
review_count = ratings_movies.groupby(['movie_id']).size().reset_index(name='review_count')

# %%
avg_ratings = ratings_movies.groupby('movie_id')['rating_val'].mean().reset_index(name='avg_rating')

# %%
movie_metrics = pd.merge(avg_ratings, review_count, on='movie_id')

# %%
movie_data = pd.merge(movie_data, movie_metrics, on='movie_id', how='left')

# Step 5: Handle missing values (movies without reviews)
movie_data['avg_rating'] = movie_data_with_metrics['avg_rating'].fillna(0)
movie_data['review_count'] = movie_data_with_metrics['review_count'].fillna(0).astype(int)

# %%
movie_data
# Out:
#                              _id                          movie_id  \
# 0       5fc85f606758f69634496fd3                   football-freaks
# 1       5fc85ff26758f696344ace0c                    aftermath-1960
# 2       5fc85f606758f69634496fcd           where-chimneys-are-seen
# 3       5fc85f606758f69634496fd1            the-musicians-daughter
# 4       5fc85f606758f69634496fd4              50-years-of-fabulous
# ...                          ...                               ...
# 285958  6239f32da936b95600b301d8  the-western-world-of-sailor-moon
# 285959  6239f32da936b95600b301e8                        shadowplay
# 285960  6239f32da936b95600b301f2                   only-always-you
# 285961  6239f32da936b95600b301fb   one-night-stand-ellen-degeneres
# 285962  6239f32da936b95600b30204              the-french-democracy
#
#                     movie_title original_language  \
# 0               Football Freaks                en
# 1                     Aftermath                en
# 2       Where Chimneys Are Seen                ja
# 3       The Musician's Daughter                en
# 4          50 Years of Fabulous                en
# ...                         ...               ...
# 285958                      NaN               NaN
# 285959                      NaN               NaN
# 285960                      NaN               NaN
# 285961                      NaN               NaN
# 285962                      NaN               NaN
#
#                                                  overview  popularity  \
# 0       Football crazy, football mad. Don’t watch this...       0.600
# 1       Aftermath was the pilot for an unsold TV serie...       0.600
# 2       Gosho’s most celebrated film both in Japan and...       1.568
# 3       Carl Wagner's good wife was dying. His heart b...       0.600
# 4       50 Years of Fabulous recounts the rich history...       0.600
# ...                                                   ...         ...
# 285958                                                NaN         NaN
# 285959                                                NaN         NaN
# 285960                                                NaN         NaN
# 285961                                                NaN         NaN
# 285962                                                NaN         NaN
#
#                 production_countries release_date  runtime  year_released  \
# 0                 ["United Kingdom"]   1971-12-05      0.0         1971.0
# 1                                 []   1960-04-17     22.0         1960.0
# 2                          ["Japan"]   1953-03-05    108.0         1953.0
# 3       ["United States of America"]   1911-12-12     15.0         1911.0
# 4                                 []   2018-05-17     75.0         2018.0
# ...                              ...          ...      ...            ...
# 285958                           NaN          NaN      NaN            NaN
# 285959                           NaN          NaN      NaN            NaN
# 285960                           NaN          NaN      NaN            NaN
# 285961                           NaN          NaN      NaN            NaN
# 285962                           NaN          NaN      NaN            NaN
#
#         avg_rating  review_count
# 0         7.000000             1
# 1         8.000000             1
# 2         8.238095            21
# 3         4.666667             3
# 4         6.000000             5
# ...            ...           ...
# 285958    0.000000             0
# 285959    0.000000             0
# 285960    0.000000             0
# 285961    0.000000             0
# 285962    0.000000             0
#
# [285963 rows x 12 columns]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(
    movie_data['review_count'],
    movie_data['avg_rating'],
    alpha=0.6,
    color='blue'
)
plt.title("Review Count vs Average Rating", fontsize=16)
plt.xlabel("Review Count", fontsize=14)
plt.ylabel("Average Rating", fontsize=14)
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Notes
# - Could be interesting to use average rating as a feature as users are able to see that before they make a rating, and this could influence their rating
# - I think that we should start by using a similar model to assignment 2. We can look at collaborative filtering approaches soley based on user to user comparisons
# - Then once we add in features potentially using a factorization model, we can see how these interactions can potentially improve our model.
# - Other features that we could potentially use are run time, genre, release date etc, to see how these decisions may impact a user's rating.
# - I feel like doing something like this will be sufficient to demostrate a deeper understanding of the material covered, rather than just what we did in assignment1.
