# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from collections import defaultdict
from sklearn import linear_model
from implicit import bpr
from surprise import SVD, Reader, Dataset
from sklearn.model_selection import train_test_split
import scipy
from scipy.sparse import csr_matrix
from fastFM import als
from scipy.spatial import distance

# %%
rating_data = pd.read_csv("ratings_export.csv")

# %%
rating_data
# Out:
#                                _id             movie_id  rating_val  \
# 0         5fc57c5d6758f6963451a07f           feast-2014           7
# 1         5fc57c5d6758f6963451a063          loving-2016           7
# 2         5fc57c5d6758f6963451a0ef     scripted-content           7
# 3         5fc57c5d6758f6963451a060           the-future           4
# 4         5fc57c5c6758f69634519398                 mank           5
# ...                            ...                  ...         ...
# 11078162  6239f4f1a936b95600b3d798              alien-3           6
# 11078163  6239f4f1a936b95600b3d799  battleship-potemkin           7
# 11078164  6239f4f1a936b95600b3d79e               pusher           6
# 11078165  6239f4f1a936b95600b3d7a1    wild-strawberries           7
# 11078166  6239f4f1a936b95600b3d7a2               x-2022           5
#
#              user_id
# 0         deathproof
# 1         deathproof
# 2         deathproof
# 3         deathproof
# 4         deathproof
# ...

# %% [markdown]
# We have 11078167 reviews.

# %%
movie_data = pd.read_csv("movie_data.csv", on_bad_lines='skip')

# %%
movie_data = movie_data.drop(["image_url", "imdb_id", "spoken_languages", "tmdb_id", "tmdb_link", "vote_average", "vote_count", "imdb_link"], axis = 1)

# %%
nulls_per_column = movie_data.isnull().sum()
print("Null values per column:")
print(nulls_per_column)
# Out:
# Null values per column:
# _id                         0
# genres                  10977
# movie_id                  347
# movie_title              2510
# original_language       10977
# overview                24601
# popularity              11091
# production_countries    11109
# release_date            15009
# runtime                 16020
# year_released            8127
# dtype: int64

# %%
user_data = pd.read_csv("users_export.csv")

# %%
user_data
# Out:
#                            _id        display_name  num_ratings_pages  \
# 0     5fc4172ec6cd28ebd99dd0e2                Lucy               32.0
# 1     5fc4172ec6cd28ebd99dd0ea         Matt Singer               52.0
# 2     5fc4172ec6cd28ebd99dd0ed          Sean Baker               21.0
# 3     5fc4172ec6cd28ebd99dd0ee                iana               37.0
# 4     5fc419171ebf67b9fbe48615               Lizzy               57.0
# ...                        ...                 ...                ...
# 8134  6239b430a936b956009c993c  Máté Turi-Mészáros                NaN
# 8135  6239cbf7a936b95600a2d24c                Finn                NaN
# 8136  6239d254a936b95600a4472f              Daniel                NaN
# 8137  6239df37a936b95600aa7aa5      ButterflyFilms                NaN
# 8138  6239e55ba936b95600ae2012                 Flo                NaN
#
#       num_reviews         username
# 0            1650       deathproof
# 1            1915       superpulse
# ...

# %%
ratings_movies = pd.merge(rating_data, movie_data, on='movie_id', how='left')

# %%
ratings_movies = ratings_movies.drop(["_id_x", "_id_y"], axis=1)

# %%
ratings_movies
# Out:
#                      movie_id  rating_val     user_id  \
# 0                  feast-2014           7  deathproof
# 1                 loving-2016           7  deathproof
# 2            scripted-content           7  deathproof
# 3                  the-future           4  deathproof
# 4                        mank           5  deathproof
# ...                       ...         ...         ...
# 11080238              alien-3           6    turnitip
# 11080239  battleship-potemkin           7    turnitip
# 11080240               pusher           6    turnitip
# 11080241    wild-strawberries           7    turnitip
# 11080242               x-2022           5    turnitip
#
#                                            genres          movie_title  \
# 0         ["Animation","Comedy","Drama","Family"]                Feast
# 1                             ["Romance","Drama"]               Loving
# 2                                      ["Comedy"]     Scripted Content
# ...

# %%
nulls_per_column = ratings_movies.isnull().sum()
print("Null values per column:")
print(nulls_per_column)
# Out:
# Null values per column:
# movie_id                  2082
# rating_val                   0
# user_id                      0
# genres                  170547
# movie_title              12133
# original_language       170547
# overview                194263
# popularity              170899
# production_countries    170899
# release_date            177847
# runtime                 177702
# year_released            23225
# dtype: int64

# %%
# Since we have over 11 million reviews, we can remove reviews 
# that have null movie ids, runtimes, year released, movie titles, and original languages. 
ratings_movies = ratings_movies.dropna(subset=['runtime', 'year_released', 'movie_id', 'movie_title'])

# %%
ratings_movies
# Out:
#                      movie_id  rating_val     user_id  \
# 0                  feast-2014           7  deathproof
# 1                 loving-2016           7  deathproof
# 2            scripted-content           7  deathproof
# 3                  the-future           4  deathproof
# 4                        mank           5  deathproof
# ...                       ...         ...         ...
# 11080238              alien-3           6    turnitip
# 11080239  battleship-potemkin           7    turnitip
# 11080240               pusher           6    turnitip
# 11080241    wild-strawberries           7    turnitip
# 11080242               x-2022           5    turnitip
#
#                                            genres          movie_title  \
# 0         ["Animation","Comedy","Drama","Family"]                Feast
# 1                             ["Romance","Drama"]               Loving
# 2                                      ["Comedy"]     Scripted Content
# ...

# %%
review_count = ratings_movies.groupby(['movie_id']).size().reset_index(name='review_count')
avg_ratings = ratings_movies.groupby('movie_id')['rating_val'].mean().reset_index(name='avg_rating')

movie_metrics = pd.merge(avg_ratings, review_count, on='movie_id')
ratings_movies = pd.merge(ratings_movies, movie_metrics, on='movie_id', how='left')
movie_data = pd.merge(movie_data, movie_metrics, on='movie_id', how='left')

# %%
# Remove any movie that hasn't been rated
movie_data = movie_data.dropna(subset=['review_count'])
movie_data
# Out:
#                              _id                 genres  \
# 0       5fc85f606758f69634496fd3  ["Music","Animation"]
# 1       5fc85ff26758f696344ace0c                     []
# 2       5fc85f606758f69634496fcd              ["Drama"]
# 3       5fc85f606758f69634496fd1              ["Drama"]
# 4       5fc85f606758f69634496fd4        ["Documentary"]
# ...                          ...                    ...
# 285952  6239e60ea936b95600aeb9bb        ["Documentary"]
# 285953  6239e60ea936b95600aeb9cf                     []
# 285954  6239e60fa936b95600aeb9e4             ["Comedy"]
# 285955  6239e60fa936b95600aeb9e5             ["Comedy"]
# 285956  6239e61ba936b95600aed5d3  ["Horror","Thriller"]
#
#                            movie_id                  movie_title  \
# 0                   football-freaks              Football Freaks
# 1                    aftermath-1960                    Aftermath
# 2           where-chimneys-are-seen      Where Chimneys Are Seen
# ...

# %%
# We also want to remove any movies that have very few reviews. These movies will be incredibly difficult to 
# predict a rating for, and it is unlikely we would want to reccomend a movie that hasn't been reviewed. 
# Remove movies that have only been rated less than twenty times. 
ratings_movies = ratings_movies[ratings_movies['review_count'] >= 20]
ratings_movies.shape
# Out:
# (10035122, 14)

# %% [markdown]
# As we can see, we still have over 10 million movie reviews to work with which will be more than enough to predict how a user will rate a certain movie.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(
    ratings_movies['review_count'],
    ratings_movies['avg_rating'],
    alpha=0.4,
    color='blue'
)
plt.title("Review Count vs Average Rating", fontsize=16)
plt.xlabel("Review Count", fontsize=14)
plt.ylabel("Average Rating", fontsize=14)
plt.grid(True, alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(
    ratings_movies['year_released'],
    ratings_movies['avg_rating'],
    alpha=0.4,
    color='blue'
)
plt.title("Year Released vs Average Rating", fontsize=16)
plt.xlabel("Year Released", fontsize=14)
plt.ylabel("Average Rating", fontsize=14)
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Notes
# - Could be interesting to use average rating as a feature as users are able to see that before they make a rating, and this could influence their rating
# - I think that we should start by using a similar model to assignment 2. We can look at collaborative filtering approaches soley based on user to user comparisons
# - Then once we add in features potentially using a factorization model, we can see how these interactions can potentially improve our model.
# - Other features that we could potentially use are run time, genre, release date etc, to see how these decisions may impact a user's rating.
# - I feel like doing something like this will be sufficient to demostrate a deeper understanding of the material covered, rather than just what we did in assignment1.

# %%
ratings_movies = ratings_movies.reset_index(drop=True)

# %% [markdown]
# # Begin training Models
#
# We can start by building tuples like the ones in assignment 1 with just the user, movie, and rating. We can then add back in other features using the metadata from the movies_data dataset.

# %%
def MSE(predictions, labels):
    differences = [(x-y)**2 for x,y in zip(predictions,labels)]
    return sum(differences) / len(differences)

# %%
trainset, testset = train_test_split(ratings_movies, test_size=.25, random_state=48)

# %%
dataTrain = list(trainset[['user_id', 'movie_id', 'rating_val']].itertuples(index=False, name=None))
dataTest = list(testset[['user_id', 'movie_id', 'rating_val']].itertuples(index=False, name=None))

# %% [markdown]
# ### Baseline

# %%
trainRatings = [r[2] for r in dataTrain]
globalAverage = sum(trainRatings) * 1.0 / len(trainRatings)

# %%
globalAverage
# Out:
# 6.551984025172391

# %%
validMSE = 0
for u,m,r in dataTest:
    sse = (r - globalAverage)**2
    validMSE += sse

validMSE /= len(dataTest)

print("Baseline MSE on test set (predictions using training average) = " + str(validMSE))
# Out:
# Baseline MSE on test set (predictions using training average) = 4.284943513253898

# %% [markdown]
# ### Note for later
# - too lazy to do a collaboritive filtering model from similarties alone like we did in class right now, but should do later to show improvement

# %% [markdown]
# ### SVD

# %%
model2 = SVD()

# %%
reader = Reader(rating_scale=(0, 10))
svdDataTrain = Dataset.load_from_df(trainset[['user_id', 'movie_id', 'rating_val']], reader).build_full_trainset()

# %%
model2.fit(svdDataTrain)
predictions = model2.test(dataTest)

# %%
labels = [d[2] for d in dataTest]
predictions = [d.est for d in predictions]

# %%
mse = MSE(predictions, labels)
print("SVD model without hyperparamter turning = " + str(mse))
# Out:
# SVD model without hyperparamter turning = 1.9276286262957771

# %% [markdown]
# ### Note:
# - too lazy to tune hyperparamters with gridsearch, as I also expect that will take a very long time to run, but should do that later

# %% [markdown]
# ### Factorization model
# - lets see if the additional features that we extracted at the beginning will lead to an improvement on our MSE

# %%
userIDs = {u: idx for idx, u in enumerate(ratings_movies['user_id'].unique())}
movieIDs = {i: idx for idx, i in enumerate(ratings_movies['movie_id'].unique())}

# Create a mapping of user-movie interactions
ratings_movies['user_idx'] = ratings_movies['user_id'].map(userIDs)
ratings_movies['movie_idx'] = ratings_movies['movie_id'].map(movieIDs)

nUsers = len(userIDs)
nMovies = len(movieIDs)

# %%
rows = ratings_movies['user_idx']
cols = ratings_movies['movie_idx'] + nUsers
data = np.ones(len(ratings_movies))

X = csr_matrix((data, (rows, cols)), shape=(len(ratings_movies), nUsers + nMovies))

# Target variable (ratings)
y = ratings_movies['rating_val'].values

# %%
X
# Out:
# <10035122x50059 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10035122 stored elements in Compressed Sparse Row format>

# %%
train_indices = trainset.index
test_indices = testset.index

# Split X and y using the indices
X_train = X[train_indices]
X_test = X[test_indices]
y_train = y[train_indices]
y_test = y[test_indices]
X_train

# %%
fm = als.FMRegression(n_iter=10, init_stdev=0.1, rank=5, l2_reg_w=0.1, l2_reg_V=0.5)

# %%
fm.fit(X_train, y_train)

# %%
y_pred = fm.predict(X_test)

# %%
mse_fm = MSE(y_pred, y_test)
print("Factorization model without hyperparamter turning = " + str(mse))
