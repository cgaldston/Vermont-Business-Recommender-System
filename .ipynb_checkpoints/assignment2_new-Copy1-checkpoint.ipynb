# %%
import numpy as np
import pandas as pd
import seaborn as sns
import json
import matplotlib.pyplot as plt
import time
import sklearn
from collections import defaultdict
from sklearn import linear_model
from implicit import bpr
from surprise import SVD, Reader, Dataset
from sklearn.model_selection import train_test_split
import scipy.sparse as sp
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from surprise.model_selection import GridSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from datetime import datetime
import random
import dateutil.parser
from fastFM import als
from sklearn.preprocessing import MinMaxScaler
import string
from xgboost import XGBRegressor
from collections import Counter
from sklearn.metrics import mean_squared_error
from scipy.sparse import hstack
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.models import Word2Vec
from sklearn.linear_model import Ridge
from nltk.stem.porter import *

# %%
def parseData(fname):
    for l in open(fname):
        yield json.loads(l)

# %%
data = list(parseData("review-Vermont.json"))

# %%
metadata = list(parseData("meta-Vermont.json"))

# %% [markdown]
# # EDA

# %%
df = pd.DataFrame(data)
metadata_df = pd.DataFrame(metadata)

# %%
df.head()
# Out:
#                  user_id               name           time  rating  \
# 0  104490523034805396984       Tia McCarthy  1629987079369     5.0
# 1  112062684820633635547  Rochelle Weitzner  1626442303453     5.0
# 2  110048311042721875910     Baxter Holland  1627319568225     5.0
# 3  106174372090234957142        Jack Droppa  1625223629975     5.0
# 4  106238734329148428463           Ty Danco  1630520930973     5.0
#
#                                                 text  pics  \
# 0  The Royal Group recently performed standard te...  None
# 1  I can't say enough great things about The Roya...  None
# 2  The Royal Group has done work for us over many...  None
# 3  The Royal Group was fantastic to work with. I ...  None
# 4  Have used in different houses, installing mult...  None
#
#                                                 resp  \
# 0  {'time': 1629988531658, 'text': 'Tia, You rock...
# 1  {'time': 1626444234168, 'text': 'Morning Roche...
# 2  {'time': 1627319913364, 'text': 'Baxter,
#
# I tr...
# 3  {'time': 1625224706775, 'text': 'Morning Jack,...
# 4  {'time': 1630521923452, 'text': 'Thanks so muc...
#
#                                  gmap_id
# 0  0x89e02445cb9db457:0x37f42bff4edf7a43
# 1  0x89e02445cb9db457:0x37f42bff4edf7a43
# 2  0x89e02445cb9db457:0x37f42bff4edf7a43
# 3  0x89e02445cb9db457:0x37f42bff4edf7a43
# 4  0x89e02445cb9db457:0x37f42bff4edf7a43

# %%
metadata_df.head()
# Out:
#                        name  \
# 0               Royal Group
# 1  Foxglove Farm and Forest
# 2              Carr's Gifts
# 3                     Midas
# 4             Keyser Energy
#
#                                              address  \
# 0  Royal Group, 150 Woodstock Ave, Rutland, VT 05701
# 1  Foxglove Farm and Forest, 777 Delorm Rd, Leice...
# 2      Carr's Gifts, 21 Center St, Brandon, VT 05733
# 3  Midas, 207 US Route 4 E, Woodstock Ave, Rutlan...
# 4  Keyser Energy, 77 Grove St Suite G102, Rutland...
#
#                                  gmap_id description   latitude  longitude  \
# 0  0x89e02445cb9db457:0x37f42bff4edf7a43        None  43.615537 -72.960497
# 1  0x4cb549e8877cf0d7:0xe8f003e6d73392ae        None  43.855743 -73.088180
# 2  0x4cb54a301f3518f7:0x39af4eda1efb9117        None  43.799002 -73.088269
# 3  0x89e024446398691f:0x4011d3a0f8636036        None  43.623157 -72.953303
# 4  0x89e0247d160d7263:0x32e4f01896e33f3b        None  43.611359 -72.981580
#
#                                             category  avg_rating  \
# 0  [Security system supplier, Fire protection equ...         4.9
# 1                  [Indoor lodging, Farm, Gift shop]         5.0
# 2                                        [Gift shop]         4.9
# 3  [Auto repair shop, Brake shop, Muffler shop, O...         4.3
# 4  [Heating oil supplier, Air conditioning contra...         4.7
#
#    num_of_reviews price                                              hours  \
# 0             148  None  [[Thursday, 8AM–5PM], [Friday, 8AM–5PM], [Satu...
# 1               3  None                                               None
# 2              13  None  [[Wednesday, 10AM–5PM], [Thursday, 10AM–5PM], ...
# 3              48  None  [[Wednesday, 7:30AM–5PM], [Thursday, 7:30AM–5P...
# 4              68  None  [[Wednesday, 8AM–4:30PM], [Thursday, 8AM–4:30P...
#
#                                                 MISC  \
# 0  {'Accessibility': ['Wheelchair accessible entr...
# 1                                               None
# 2  {'Service options': ['In-store shopping', 'Del...
# 3  {'Accessibility': ['Wheelchair accessible entr...
# 4                                               None
#
#                        state  \
# 0         Closed ⋅ Opens 8AM
# 1                       None
# 2    Closed ⋅ Opens 10AM Thu
# 3  Closed ⋅ Opens 7:30AM Thu
# 4     Closed ⋅ Opens 8AM Thu
#
#                                     relative_results  \
# 0  [0x89e0245c4c5c7d2d:0x97bca40a0223d767, 0x89e0...
# 1                                               None
# 2  [0x4cb54b57c4f3123b:0x3d4e844c93c72568, 0x4cb5...
# 3  [0x89e02489914d34f9:0x31610a8d324af00d, 0x89e0...
# 4  [0x89e0248f040ed50d:0x20f29a9817069602, 0x89e0...
#
#                                                  url
# 0  https://www.google.com/maps/place//data=!4m2!3...
# 1  https://www.google.com/maps/place//data=!4m2!3...
# 2  https://www.google.com/maps/place//data=!4m2!3...
# 3  https://www.google.com/maps/place//data=!4m2!3...
# 4  https://www.google.com/maps/place//data=!4m2!3...

# %%
df = df.drop(columns = ['pics', 'resp'])
metadata_df = metadata_df.drop(columns=['address', 'category', 'MISC', 'state', 'relative_results', 'url'])
df.shape
# Out:
# (852203, 6)

# %%
nulls_per_column = df.isnull().sum()
print("Null values per column:")
print(nulls_per_column)
# Out:
# Null values per column:
# user_id     10293
# name            0
# time            0
# rating      10293
# text       345133
# gmap_id         0
# dtype: int64

# %%
# Drop reviews without rating and text
df = df.dropna(subset=['rating', 'text'])
data = [record for record in data if record.get('rating') is not None]
data = [record for record in data if record.get('text') is not None]
df.shape
# Out:
# (496777, 6)

# %%
nulls_per_column = metadata_df.isnull().sum()
print("Null values per column:")
print(nulls_per_column)
# Out:
# Null values per column:
# name                 0
# gmap_id              0
# description       9651
# latitude             0
# longitude            0
# avg_rating           0
# num_of_reviews       0
# price             9567
# hours             3358
# dtype: int64

# %%
df['user_id'].value_counts().describe()
# Out:
# count    203213.000000
# mean          2.444612
# std           5.501693
# min           1.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max         296.000000
# Name: count, dtype: float64

# %%
user_review_count = Counter([entry['user_id'] for entry in data])

thresholds = [1, 3, 5, 10]

for t in thresholds:
    # Find users with reviews below the threshold
    dropped_users = {user: count for user, count in user_review_count.items() if count < t}
    # Calculate total reviews dropped
    reviews_dropped = sum(dropped_users.values())
    print(f"Threshold: {t}, Users Dropped: {len(dropped_users)}, Reviews Dropped: {reviews_dropped}")
# Out:
# Threshold: 1, Users Dropped: 0, Reviews Dropped: 0
# Threshold: 3, Users Dropped: 165913, Reviews Dropped: 195466
# Threshold: 5, Users Dropped: 184486, Reviews Dropped: 257816
# Threshold: 10, Users Dropped: 195773, Reviews Dropped: 329924

# %%
min_reviews = 3
data = [entry for entry in data if user_review_count[entry['user_id']] >= min_reviews]
df = pd.DataFrame(data)

# %% [markdown]
# Users with only one review will be hard to predict ratings for as collaborative filtering examines similarities between user preferences.

# %%
df.shape
# Out:
# (301311, 8)

# %%
df['user_id'].value_counts().describe()
# Out:
# count    37300.000000
# mean         8.078043
# std         11.197622
# min          3.000000
# 25%          3.000000
# 50%          5.000000
# 75%          8.000000
# max        296.000000
# Name: count, dtype: float64

# %%
df['datetime'] = pd.to_datetime(df['time'], unit='ms') 
df['month'] = df['datetime'].dt.month 
df['hour'] = df['datetime'].dt.hour

# %%
metadata_df.plot(kind="scatter", x="longitude", y="latitude", alpha=0.4)
plt.title("Geographic Distribution of Businesses")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.xlim(-73.5, -71.0)  # Vermont longitude range
plt.ylim(42.7, 45.1) 
plt.show()

# %%
import contextily as ctx
import matplotlib.pyplot as plt
import geopandas as gpd
from shapely.geometry import Point

vermont_bounds = {
    'west': -73.437,   # Western boundary
    'east': -71.464,   # Eastern boundary
    'south': 42.730,   # Southern boundary
    'north': 45.016    # Northern boundary
}

# Create geometry column from longitude and latitude
geometry = [Point(xy) for xy in zip(metadata_df['longitude'], metadata_df['latitude'])]
geo_metadata_vermont = gpd.GeoDataFrame(metadata, geometry=geometry)

# Set the Coordinate Reference System (CRS) to WGS84 (latitude and longitude)
geo_metadata_vermont.crs = "EPSG:4326"

# Plot the GeoDataFrame
fig, ax = plt.subplots(figsize=(10, 10))
geo_metadata_vermont.plot(ax=ax, color='blue', alpha=0.6, markersize=5)

# Set axes limits
ax.set_xlim(vermont_bounds['west'], vermont_bounds['east'])
ax.set_ylim(vermont_bounds['south'], vermont_bounds['north'])

# Add basemap
ctx.add_basemap(
    ax,
    source=ctx.providers.OpenStreetMap.Mapnik,
    crs=geo_metadata_vermont.crs.to_string(),
    zoom=10
)

# Set plot title and labels
plt.title("Geographic Distribution of Businesses in Vermont")
plt.xlabel("Longitude")
plt.ylabel("Latitude")

plt.tight_layout()
plt.show()

# %%
# Look into reccomending by location

# %%
df['datetime'] = pd.to_datetime(df['time'], unit='ms')  # Convert UNIX time to datetime
df['month'] = df['datetime'].dt.month  # Extract month

# Group by month and calculate average rating
seasonal_trends = df.groupby('month')['rating'].mean()

# Plot seasonal trends
plt.figure(figsize=(8, 5))
plt.plot(seasonal_trends.index, seasonal_trends.values, marker='o')
plt.xticks(ticks=range(1, 13), labels=['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D'])
plt.title("Seasonal Trends")
plt.xlabel("Time of year")
plt.ylabel("Average rating")
plt.grid(True)
plt.show()

# %%
df['hour'] = df['datetime'].dt.hour

# Group by hour and calculate average rating
short_term_trends = df.groupby('hour')['rating'].mean()

# Plot short-term trends
plt.figure(figsize=(8, 5))
plt.plot(short_term_trends.index, short_term_trends.values, marker='o')
plt.xticks(ticks=range(0, 24, 2), labels=[f"{h}:00" for h in range(0, 24, 2)])
plt.title("Short-Term Trends")
plt.xlabel("Time of day")
plt.ylabel("Average rating")
plt.grid(True)
plt.show()

# %%
reviews_with_meta = pd.merge(df, metadata_df, on='gmap_id')

# %% [markdown]
# # Models

# %% [markdown]
# ### Baseline

# %%
# convert metadata to dict to more easily look up metadata later
metadata_dict = {
    d['gmap_id']: {
        'latitude': d.get('latitude', 0),
        'longitude': d.get('longitude', 0),
        'avg_rating': d.get('avg_rating', 0),
        'num_of_reviews': d.get('num_of_reviews', 0)
    }
    for d in metadata
}

# %%
def MSE(predictions, labels):
    differences = [(x-y)**2 for x,y in zip(predictions,labels)]
    return sum(differences) / len(differences)

# %%
trainset, testset = train_test_split(data, test_size=.25, random_state=48)

# %%
ratings = [r['rating'] for r in data]
globalAverage = sum(ratings) * 1.0 / len(ratings)

# %%
validMSE = 0
for d in testset:
    sse = (d['rating'] - globalAverage)**2
    validMSE += sse

validMSE /= len(testset)

print("Baseline MSE on test set (predictions using global average) = " + str(validMSE))
# Out:
# Baseline MSE on test set (predictions using global average) = 1.1374923333241382

# %%
validMSE = 0
for d in testset:
    sse = (d['rating'] - metadata_dict[d['gmap_id']]['avg_rating'])**2
    validMSE += sse

validMSE /= len(testset)

print("Baseline MSE on test set (predictions using business average) = " + str(validMSE))
# Out:
# Baseline MSE on test set (predictions using business average) = 0.9711025116822765

# %% [markdown]
# ### Note for later
# - too lazy to do a collaboritive filtering model from similarties alone like we did in class right now, but should do later to show improvement

# %% [markdown]
# ### SVD

# %%
trainset_df = pd.DataFrame(trainset)
testset_df = pd.DataFrame(testset)

# %%
model2 = SVD()

# %%
reader = Reader(rating_scale=(1, 5))
svdDataTrain = Dataset.load_from_df(trainset_df[['user_id', 'gmap_id', 'rating']], reader).build_full_trainset()
svdDataTest = list(testset_df[['user_id', 'gmap_id', 'rating']].itertuples(index=False, name=None))

# %%
model2.fit(svdDataTrain)
predictions = model2.test(svdDataTest)

# %%
labels = [d["rating"] for d in testset]
predictions = [d.est for d in predictions]

# %%
mse = MSE(predictions, labels)
print("SVD model without hyperparamter turning = " + str(mse))
# Out:
# SVD model without hyperparamter turning = 0.9045070407117858

# %%
from surprise.model_selection import GridSearchCV
data_for_gs = Dataset.load_from_df(pd.DataFrame(data)[['user_id', 'gmap_id', 'rating']], reader)
param_grid = {
    'n_factors': [50, 100],
    'n_epochs': [10, 20],  
    'lr_all': [0.002, 0.005], 
    'reg_all': [0.02, 0.05]      
}

grid_search = GridSearchCV(SVD, param_grid, measures=['rmse', 'mae'], cv=2)

grid_search.fit(data_for_gs)

print("Best RMSE Score:", grid_search.best_score['rmse'])
print("Best Parameters:", grid_search.best_params['rmse'])
# Out:
# Best RMSE Score: 0.9677866336534827
# Best Parameters: {'n_factors': 50, 'n_epochs': 20, 'lr_all': 0.005, 'reg_all': 0.05}

# %%
# from gridsearch Best RMSE Score: 0.9677866336534827
# Best Parameters: {'n_factors': 50, 'n_epochs': 20, 'lr_all': 0.005, 'reg_all': 0.05}
# best_params = grid_search.best_params['rmse']
model3 = SVD(n_factors= 50, n_epochs= 20, lr_all= 0.005, reg_all= 0.05)

model3.fit(svdDataTrain)
predictions = model3.test(svdDataTest)

# %%
labels = [d["rating"] for d in testset]
predictions = [d.est for d in predictions]

# %%
mse_svd_tuned = MSE(predictions, labels)
print("SVD model with hyperparamter turning = " + str(mse_svd_tuned))
# Out:
# SVD model with hyperparamter turning = 0.895954756292148

# %% [markdown]
# ### WordVec

# %%
merged_df = reviews_with_meta

# Prepare Features
# One-hot encode user_id and gmap_id
encoder = OneHotEncoder()
user_item_matrix = encoder.fit_transform(merged_df[['user_id', 'gmap_id']])

# Scale geographic and temporal features
scaler = StandardScaler()
geographic_features = scaler.fit_transform(merged_df[['latitude', 'longitude']])
temporal_features = pd.get_dummies(merged_df[['month', 'hour']])

# Generate Word2Vec Embeddings for Text
merged_df['processed_text'] = merged_df['text'].fillna('').str.split()  # Tokenize text
word2vec_model = Word2Vec(sentences=merged_df['processed_text'], vector_size=50, min_count=1, window=5, sg=1)

# %%
def compute_text_embedding(text_tokens):
    if not text_tokens:  # Handle empty text
        return np.zeros(word2vec_model.vector_size)
    embeddings = [word2vec_model.wv[token] for token in text_tokens if token in word2vec_model.wv]
    return np.mean(embeddings, axis=0) if embeddings else np.zeros(word2vec_model.vector_size)

# %%
text_features = np.array([compute_text_embedding(tokens) for tokens in merged_df['processed_text']])

# Combine all features into a single sparse matrix
feature_matrix = hstack([user_item_matrix, geographic_features, temporal_features, text_features])

# Target variable
target = merged_df['rating']

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(feature_matrix, target, test_size=0.25, random_state=42)

# Ridge Regression with GridSearchCV for Hyperparameter Tuning
param_grid = {
    'alpha': [0.1, 1.0, 10.0, 100.0],  # Regularization strength
    'fit_intercept': [True, False]     # Whether to include an intercept
}

ridge = Ridge()
grid_search = GridSearchCV(ridge, param_grid, cv=3, scoring='neg_mean_squared_error')
grid_search.fit(X_train, y_train)

# Best parameters
print("Best parameters:", grid_search.best_params_)

# Evaluate the model on the test set
best_ridge = grid_search.best_estimator_
y_pred = best_ridge.predict(X_test)

# Calculate evaluation metrics
mse_ridge = MSE(y_pred, y_test)

print(f"Best Ridge Regression MSE: {mse_ridge}")
# Out:
# Best parameters: {'alpha': 10.0, 'fit_intercept': True}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 30
#      27 y_pred = best_ridge.predict(X_test)
#      29 # Calculate evaluation metrics
# ---> 30 mse_ridge = MSE(y_pred, y_test)
#      32 print(f"Best Ridge Regression MSE: {mse_ridge}")
#
# NameError: name 'MSE' is not defined

# %% [markdown]
# ### Temporal

# %%
ratingsTime = []
for d in data:
    ratingsTime.append((d["time"], d["rating"]))

# %%
ratingsTime.sort()
len(ratingsTime)
# Out:
# 301311

# %%
wSize = 1000
x = [r[0] for r in ratingsTime] # as raw times
y = [r[1] for r in ratingsTime] # ratings
x_datetime = [datetime.fromtimestamp(t / 1000) for t in x]
xu = [time.mktime(d.timetuple()) for d in x_datetime]

# %%
xSum = sum(xu[:wSize])
ySum = sum(y[:wSize])
sliding = []

# %%
for i in range(wSize,len(x)-1):
    xSum += xu[i] - xu[i-wSize]
    ySum += y[i] - y[i-wSize]
    sliding.append((xSum*1.0/wSize,ySum*1.0/wSize))

# %%
X = [a[0] for a in sliding]
Y = [a[1] for a in sliding]

# %%
from datetime import datetime

# Define the start and end dates for the x-axis
start_date = datetime.fromtimestamp(X[0])  # Convert the first timestamp to datetime
end_date = datetime.fromtimestamp(X[-1])  # Convert the last timestamp to datetime

# Generate tick locations and labels
num_ticks = 10  # Number of ticks on the x-axis
tick_dates = [start_date + (end_date - start_date) * i / (num_ticks - 1) for i in range(num_ticks)]
tick_locations = [d.timestamp() for d in tick_dates]  # Convert datetime to UNIX timestamps
tick_labels = [d.strftime("%b %Y") for d in tick_dates]  # Format dates as "Month Year"

# Plot the data
plt.figure(figsize=(12, 6))
plt.plot(X[::2500], Y[::2500], label="5000 rating window", color='k')

# Add custom ticks and labels for the x-axis
plt.xticks(tick_locations, tick_labels, rotation=45)  # Rotate labels for better readability

# Add axis limits and labels
plt.xlim(X[0], X[-1])
plt.ylabel("Rating")
plt.xlabel("Date")
plt.legend(loc="best", fontsize=8)
plt.title("Ratings over time (sliding windows)")

# Adjust layout
plt.tight_layout()
plt.show()

# %%
from datetime import datetime

# Define the specific year to show (e.g., 2021)
start_date = datetime(2019, 1, 1)
end_date = datetime(2019, 12, 31)

# Filter X and Y to only include data within the specified year
X_filtered = [x for x in X if start_date.timestamp() <= x <= end_date.timestamp()]
Y_filtered = Y[:len(X_filtered)]  # Adjust Y to match the filtered X

# Generate tick locations and labels for each month of the year
tick_dates = [datetime(2019, month, 1) for month in range(1, 13)]  # Start of each month
tick_locations = [d.timestamp() for d in tick_dates]  # Convert datetime to UNIX timestamps
tick_labels = [d.strftime("%b") for d in tick_dates]  # Format as "Jan", "Feb", etc.

# Plot the data
plt.figure(figsize=(12, 6))
plt.plot(X_filtered, Y_filtered, label="Ratings in 2021", color='k')

# Add custom ticks and labels for the x-axis
plt.xticks(tick_locations, tick_labels, rotation=45)  # Rotate labels for better readability

# Add axis limits and labels
plt.xlim(start_date.timestamp(), end_date.timestamp())
plt.ylabel("Rating")
plt.xlabel("Month")
plt.legend(loc="best", fontsize=8)
plt.title("Ratings over time (2021 only)")

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# Cool to notice drop off in ratings over covid

# %% [markdown]
# ### unsure what im doing

# %%
userIDs,itemIDs = {},{}

for d in data:
    u,i = d['user_id'],d['gmap_id']
    if not u in userIDs: userIDs[u] = len(userIDs)
    if not i in itemIDs: itemIDs[i] = len(itemIDs)

nUsers,nItems = len(userIDs),len(itemIDs)

# %%
nUsers,nItems
# Out:
# (37300, 10692)

# %%
userIDs = {}
itemIDs = {}
interactions = []
interactionsPerUser = defaultdict(list)

for d in data:
    u = d['user_id']
    i = d['gmap_id']
    t = d['time']
    r = d['rating']
    if not u in userIDs: userIDs[u] = len(userIDs)
    if not i in itemIDs: itemIDs[i] = len(itemIDs)
    interactions.append((t,u,i,r))

# %%
interactions.sort()

# %%
interactionsPerItem = defaultdict(list)
interactionsPerUser = defaultdict(list)
for t,u,i,r in interactions:
    interactionsPerItem[i].append((t,u,r))
    interactionsPerItem[i].append((t,i,r))

# %%
random.shuffle(interactions)

# %%
def feat(t,u,i):
    older = [r for (q,u,r) in interactionsPerItem[i] if q < t] # Collect previous ratings
    f = []
    for k in range(1,6):
        try:
            f += [0,older[-k]] # Previous rating
        except Exception as e:
            f += [1,0] # Or missing value indicator if we don't have history of length k
    if len(older):
        f += [0,sum(older)/len(older)] # Add feature for the average (going beyond just last k)
    else:
        f += [1,0] # Missing value indicator if no interaction history
    return f + [1]

# %%
X = [feat(t,u,i) for t,u,i,_ in interactions]
y = [r for _,_,_,r in interactions]

# %%
XF = sp.lil_matrix((len(interactions), nUsers + len(X[0])))

# %%
for n in range(len(interactions)):
    _,u,i,r = interactions[n]
    user = userIDs[u]
    XF[n,user] = 1
    for j in range(len(X[n])): # Copy features from previous model
        XF[n,nUsers+j] = X[n][j]

# %%
fm = als.FMRegression(n_iter=100, rank=2, l2_reg_w=0.1, l2_reg_V=0.5)

# %%
y = np.array(y)
Xtrain, Xtest, ytrain, ytest = train_test_split(XF, y, test_size=0.2, random_state=48)

# %%
fm.fit(Xtrain, ytrain)
# Out:
# FMRegression(l2_reg_V=0.5, rank=2)

# %%
y_pred = fm.predict(Xtest)

# %%
MSE(y_pred, ytest)
# Out:
# 1.2485398047630922

# %%
punctuation = set(string.punctuation)
def feature(datum, words, wordId, tolower=True, removePunct=True):
    feat = [0]*len(words)
    r = datum['text']
    if tolower:
        r = r.lower()
    if removePunct:
        r = ''.join([c for c in r if not c in punctuation])
    for w in r.split():
        if w in words:
            feat[wordId[w]] += 1
    feat.append(1) # offset
    return feat

# %%
def process_text(dSize = 1000, tolower=True, removePunct=True):
    wordCount = defaultdict(int)
    punctuation = set(string.punctuation)
    for d in trainset: # Strictly, should just use the *training* data to extract word counts
        r = d['text']
        if tolower:
            r = r.lower()
        if removePunct:
            r = ''.join([c for c in r if not c in punctuation])
        for w in r.split():
            wordCount[w] += 1

    counts = [(wordCount[w], w) for w in wordCount]
    counts.sort()
    counts.reverse()
    
    words = [x[1] for x in counts[:dSize]]
    
    wordId = dict(zip(words, range(len(words))))
    wordSet = set(words)
    
    return words, wordId, tolower, removePunct

# %%
words, wordId, tolower, removePunct = process_text(1500, True, True)

# %%
X = [feature(d, words, wordId, tolower, removePunct) for d in trainset]
y = [d['rating'] for d in trainset]

Xtrain, Xvalid, ytrain, yvalid = train_test_split(X, y, test_size=0.2, random_state=48)


bestModel = None
bestVal = None
bestLamb = None

ls = [0.01, 0.1, 1]
errorTrain = []
errorValid = []

for l in ls:
    model = sklearn.linear_model.Ridge(l)
    model.fit(Xtrain, ytrain)
    predictTrain = model.predict(Xtrain)
    MSEtrain = sum((ytrain - predictTrain)**2)/len(ytrain)
    errorTrain.append(MSEtrain)
    predictValid = model.predict(Xvalid)
    MSEvalid = sum((yvalid - predictValid)**2)/len(yvalid)
    errorValid.append(MSEvalid)
    print("l = " + str(l) + ", validation MSE = " + str(MSEvalid))
    if bestVal == None or MSEvalid < bestVal:
        bestVal = MSEvalid
        bestModel = model
        bestLamb = l
    
bestModel.fit(Xtrain, ytrain)
    
coefficients = bestModel.coef_
words_with_coefficients = [(word, coef) for word, coef in zip(words, coefficients)]

sorted_words = sorted(words_with_coefficients, key=lambda x: x[1], reverse=True)


Xtest = [feature(d, words, wordId, tolower, removePunct) for d in testset]
ytest = [d['rating'] for d in testset]

predictTest = bestModel.predict(Xtest)
MSEtest = MSE(predictTest, ytest)
print("MSE on test set = " + str(MSEtest))
# Out:
# l = 0.01, validation MSE = 0.6920460082789037
# l = 0.1, validation MSE = 0.6920434232819487
# l = 1, validation MSE = 0.6920178664588031
# MSE on test set = 0.6859117152489979

# %%
most_positive = sorted_words[:25] 
most_negative = sorted_words[-25:]
positive_words, positive_coefs = zip(*most_positive)
negative_words, negative_coefs = zip(*most_negative)

# Create a bar chart
fig, ax = plt.subplots(1, 2, figsize=(12, 6))

# Positive coefficients
ax[0].barh(positive_words, positive_coefs, color='green', alpha=0.7)
ax[0].set_title("Top Positive Words")
ax[0].set_xlabel("Coefficient Value")
ax[0].invert_yaxis()  # Highest value on top

# Negative coefficients
ax[1].barh(negative_words, negative_coefs, color='red', alpha=0.7)
ax[1].set_title("Top Negative Words")
ax[1].set_xlabel("Coefficient Value")
ax[1].invert_yaxis()  # Lowest value on top

plt.tight_layout()
plt.show()
# Out:
# /var/folders/nr/sn_d7m6s0zq4vml99kcs24kh0000gn/T/ipykernel_34826/2851932295.py:21: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   plt.tight_layout()
# /Users/calebgaldston/anaconda3/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 128077 (\N{THUMBS UP SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
user_ids = list({d['user_id'] for d in trainset})
item_ids = list({d['gmap_id'] for d in trainset})  # Assuming 'gmap_id' is the item identifier

# Create mappings from user_id and item_id to their indices
user_id_to_index = {user_id: idx for idx, user_id in enumerate(user_ids)}
item_id_to_index = {item_id: idx for idx, item_id in enumerate(item_ids)}
user_factors = {user_id: model3.pu[user_id_to_index[user_id]] for user_id in user_id_to_index}
item_factors = {item_id: model3.qi[item_id_to_index[item_id]] for item_id in item_id_to_index}

# %%
def extract_features(d):
    # Content-based features (e.g., from review text)
    content_features = feature(d, words, wordId, tolower, removePunct)

    metadata = metadata_dict.get(d['gmap_id'])
    # Metadata features
    metadata_features = [
        metadata['latitude'],
        metadata['longitude'],
        metadata['avg_rating'],
        metadata['num_of_reviews']
    ]

    # Time feature
    def extract_time_features(timestamp):
        dt = datetime.fromtimestamp(timestamp / 1000)  # Convert from milliseconds
        return [dt.year, dt.month, dt.day, dt.hour]

    time_features = extract_time_features(d.get('time', 0))

    return np.concatenate([content_features, metadata_features, time_features])

# %%
from sklearn.model_selection import GridSearchCV
X = [extract_features(d) for d in trainset]
y = [d['rating'] for d in trainset]

Xtrain, Xvalid, ytrain, yvalid = train_test_split(X, y, test_size=0.2, random_state=48)

param_grid = {
    'n_estimators': [100],  # Number of trees
    'learning_rate': [0.2],  # Learning rate
    'max_depth': [5]
}

grid_search = GridSearchCV(
    estimator=xgb_model,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',  # Use MSE as the scoring metric
    cv=2,  # 3-fold cross-validation
    verbose=2,
    n_jobs=-1  # Use all CPU cores
)
    
grid_search.fit(Xtrain, ytrain)

# Get the best parameters and score
best_params = grid_search.best_params_
best_score = -grid_search.best_score_  # Negative MSE to positive MSE
print("Best Parameters:", best_params)
print("Best CV Score (MSE):", best_score)

# Evaluate the model on the validation set using the best parameters
best_model = grid_search.best_estimator_
    
predictValid = best_model.predict(Xvalid)
mseValid = MSE(predictValid, yvalid)
print("MSE validation = " + str(mseValid))

Xtest = [extract_features(d) for d in testset]
ytest = [d['rating'] for d in testset]

predictTest = best_model.predict(Xtest)
MSEtest = MSE(predictTest, ytest)
print("MSE on test set = " + str(MSEtest))
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# Best Parameters: {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 100}
# Best CV Score (MSE): 0.5922825201080377
# MSE validation = 0.5904433925273304
# MSE on test set = 0.5779552380267146

# %%
def extract_features2(d):
    metadata = metadata_dict.get(d['gmap_id'])
    # Metadata features
    metadata_features = [
        metadata['latitude'],
        metadata['longitude'],
        metadata['avg_rating'],
        metadata['num_of_reviews']
    ]
    user_latent = user_factors.get(d['user_id'], [0] * len(next(iter(user_factors.values()))))

    # Latent factors for item
    item_latent = item_factors.get(d['gmap_id'], [0] * len(next(iter(item_factors.values()))))

    # Time feature
    def extract_time_features(timestamp):
        dt = datetime.fromtimestamp(timestamp / 1000)  # Convert from milliseconds
        return [dt.year, dt.month, dt.day, dt.hour]

    time_features = extract_time_features(d.get('time', 0))

    return np.concatenate([content_features, metadata_features, time_features, user_latent, item_latent])

# %%
from sklearn.model_selection import GridSearchCV
X = [extract_features2(d) for d in trainset]
y = [d['rating'] for d in trainset]

Xtrain, Xvalid, ytrain, yvalid = train_test_split(X, y, test_size=0.2, random_state=48)

param_grid = {
    'n_estimators': [50, 100],
    'learning_rate': [0.1, 0.2],
    'max_depth': [3, 5],
}

xgb_model1 = XGBRegressor(random_state=42)

grid_search = GridSearchCV(
    estimator=xgb_model1,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',  # Use MSE as the scoring metric
    cv=2,  # 2-fold cross-validation
    verbose=1,  # Enable progress updates
    n_jobs=-1  # Use all available CPU cores
)

grid_search.fit(X, y)

# Retrieve the best parameters and score
best_params = grid_search.best_params_
best_score = -grid_search.best_score_  # Convert negative MSE to positive
print("Best Parameters:", best_params)
print("Best CV MSE:", best_score)

# Train the final model with the best parameters
final_xgb_model1 = XGBRegressor(**best_params, random_state=42)
final_xgb_model1.fit(X, y)

Xtest = [extract_features2(d) for d in testset]
ytest = [d['rating'] for d in testset]

predictTest = final_xgb_model1.predict(Xtest)
MSEtest = MSE(predictTest, ytest)
print("MSE on test set = " + str(MSEtest))
# Out:
# Fitting 2 folds for each of 8 candidates, totalling 16 fits
# Best Parameters: {'learning_rate': 0.2, 'max_depth': 5, 'n_estimators': 100}
# Best CV MSE: 0.9643690359696405
# MSE on test set = 0.9313815409444163

# %%
def extract_metadata_features(d):
    metadata = metadata_dict.get(d['gmap_id'])
    metadata_features = [
        metadata['latitude'],
        metadata['longitude'],
        metadata['avg_rating'],
        metadata['num_of_reviews']
    ]
    def extract_time_features(timestamp):
        dt = datetime.fromtimestamp(timestamp / 1000)  # Convert from milliseconds
        return [dt.year, dt.month, dt.day, dt.hour]

    time_features = extract_time_features(d.get('time', 0))

    return np.concatenate([metadata_features, time_features])

# %%
# best review independent model
scaler = StandardScaler()
X = [extract_metadata_features(d) for d in trainset]
X = scaler.fit_transform(X)
y = [d['rating'] for d in trainset]

Xtrain, Xvalid, ytrain, yvalid = train_test_split(X, y, test_size=0.2, random_state=48)

bestModel = None
bestVal = None
bestLamb = None

ls = [0.01, 0.1, 1]
errorTrain = []
errorValid = []

for l in ls:
    model = sklearn.linear_model.Ridge(l)
    model.fit(Xtrain, ytrain)
    predictTrain = model.predict(Xtrain)
    MSEtrain = sum((ytrain - predictTrain)**2)/len(ytrain)
    errorTrain.append(MSEtrain)
    predictValid = model.predict(Xvalid)
    MSEvalid = sum((yvalid - predictValid)**2)/len(yvalid)
    errorValid.append(MSEvalid)
    print("l = " + str(l) + ", validation MSE = " + str(MSEvalid))
    if bestVal == None or MSEvalid < bestVal:
        bestVal = MSEvalid
        bestModel = model
        bestLamb = l
        
Xtest = [extract_metadata_features(d) for d in testset]
Xtest = scaler.fit_transform(Xtest)
ytest = [d['rating'] for d in testset]
bestModel.fit(X, y)
metadata_pred = bestModel.predict(Xtest)

# svp predictions from earlier
svd_pred = [model3.predict(d['user_id'], d['gmap_id']).est for d in testset]

# Weighted hybrid predictions
alpha = 0.81  # Weight for CF predictions
hybrid_pred = [
    alpha * cf + (1 - alpha) * meta for cf, meta in zip(svd_pred, metadata_pred)
]

# ypred_array = np.array(ytest)
# hybrid_pred_array = np.array(hybrid_pred)
# Calculate validation MSE
MSEtest = MSE(hybrid_pred, ytest)
print("MSE Test (Hybrid):", MSEtest)
# Out:
# l = 0.01, validation MSE = 0.9994479620210427
# l = 0.1, validation MSE = 0.9994479605425559
# l = 1, validation MSE = 0.9994479457622055
# MSE Test (Hybrid): 0.8907750064150773

# %%
def tune_alpha(cf_pred, metadata_pred, ytest):
    best_alpha = None
    best_mse = float('inf')
    alphas = np.linspace(0, 1, 101)  # Test alpha values from 0 to 1 in steps of 0.05

    for alpha in alphas:
        # Weighted hybrid predictions
        hybrid_pred = [
            alpha * cf + (1 - alpha) * meta for cf, meta in zip(cf_pred, metadata_pred)
        ]
        hybrid_pred_array = np.array(hybrid_pred)
        mse = np.mean((np.array(ytest) - hybrid_pred_array) ** 2)
        
        if mse < best_mse:
            best_mse = mse
            best_alpha = alpha

    return best_alpha, best_mse

# %%
tune_alpha(svd_pred, metadata_pred, ytest)
# Out:
# (0.81, 0.8907750064150776)

# %%
def recommend_businesses(user_id, n_recommendations=5):
    user_ratings = []
    
    for business_id in metadata_dict.keys():  # Iterate through all businesses
        # Check if user has already rated the business
        if any(d['user_id'] == user_id and d['gmap_id'] == business_id for d in data):
            continue  # Skip already-rated businesses
        
        # Metadata-based prediction
        metadata_features = extract_metadata_features({'gmap_id': business_id})
        metadata_features_scaled = scaler.transform([metadata_features])  # Scale metadata features
        metadata_rating = bestModel.predict(metadata_features_scaled)[0]
        
        # CF-based prediction
        cf_rating = model3.predict(user_id, business_id).est
        
        # Hybrid prediction
        hybrid_rating = alpha * cf_rating + (1 - alpha) * metadata_rating
        
        # Append the business and predicted rating
        user_ratings.append((business_id, hybrid_rating))
    
    # Sort by predicted rating and return top recommendations
    user_ratings = sorted(user_ratings, key=lambda x: x[1], reverse=True)
    return user_ratings[:n_recommendations]

# %%
recommend_businesses(110048311042721875910)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 recommend_businesses(110048311042721875910)
#
# Cell In[100], line 6, in recommend_businesses(user_id, n_recommendations)
#       2 user_ratings = []
#       4 for business_id in metadata_dict.keys():  # Iterate through all businesses
#       5     # Check if user has already rated the business
# ----> 6     if any(d['user_id'] == user_id and d['gmap_id'] == business_id for d in data):
#       7         continue  # Skip already-rated businesses
#       9     # Metadata-based prediction
#
# Cell In[100], line 6, in <genexpr>(.0)
#       2 user_ratings = []
#       4 for business_id in metadata_dict.keys():  # Iterate through all businesses
#       5     # Check if user has already rated the business
# ----> 6     if any(d['user_id'] == user_id and d['gmap_id'] == business_id for d in data):
#       7         continue  # Skip already-rated businesses
#       9     # Metadata-based prediction
#
# KeyboardInterrupt:

# %%
# Out:
# [{'user_id': '110048311042721875910',
#   'name': 'Baxter Holland',
#   'time': 1627319568225,
#   'rating': 5,
#   'text': 'The Royal Group has done work for us over many years. The latest was installing new triple track storm windows. The quality of the work was excellent. Their technicians were courteous, professional and very efficient. It was a pleasure to have them in our house. I would have no hesitation to use The Royal Group again.',
#   'pics': None,
#   'resp': {'time': 1627319913364,
#    'text': "Baxter,\n\nI truly appreciate your kind words and years of local business and support. Thanks so much for taking time to leave us a review! I'm so happy to hear that Dan and Kyle did a great job for you on this recent project.\n\nThank you again and have an excellent week\n\nRex Accavallo, CEO"},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '106238734329148428463',
#   'name': 'Ty Danco',
#   'time': 1630520930973,
#   'rating': 5,
#   'text': 'Have used in different houses, installing multiple systems. Always considerate, professional, and accessible.',
#   'pics': None,
#   'resp': {'time': 1630521923452,
#    'text': 'Thanks so much, Ty! Really appreciate the kind words and its always great working with you guys. Have a wonderful rest of the week!\n\n- Rex Accavallo, CEO'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '100853209346693947573',
#   'name': 'Tia Fineberg',
#   'time': 1619137071473,
#   'rating': 5,
#   'text': 'I’m giving The Glass Team at the Royal Group 5 stars, but they deserve 10. They replaced 2 large glass panels surrounding my massive mahogany door. It was a very difficult installation and took the better part of a day. The technicians were very professional, knowledgeable and did an outstanding job. Excellent customer service from installation to clean up. Would highly recommend The Glass Team at the Royal Group.',
#   'pics': None,
#   'resp': {'time': 1619184274759,
#    'text': "Good Morning, Tia!\n\nI heard about this project and I'm SO pleased to hear that your thrilled with the work! All of us here really appreciate your business and local support! Should you need anything in the future please let us know. You can also always contact me directly, rex@royalvt.com\n\nThanks so much Tia, have a wonderful and relaxing weekend\n\n- Rex Accavallo, CEO"},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '113559673849392806864',
#   'name': 'Andy Reid',
#   'time': 1622589986087,
#   'rating': 5,
#   'text': 'Great results from an experience with Joel. He was informative, helpful, expeditious, and very conscientious. He actually came after hours and after a long work day to meet our schedule needs. We have always had a positive experience with the Royal Group and Joel is an example of why we chose these folks. We look forward to working with the Royal Group for any future needs for security enhancement! Thank you again to Joel for great customer service.',
#   'pics': None,
#   'resp': {'time': 1622592321282,
#    'text': "Good Evening, Andy! Thank you so much for taking the time to leave such a complimentary review, I really appreciate it. I'm so happy to hear how pleased you are and that Joel took excellent care of you.\n\nThank you for keeping your support and keeping business local! We appreciate it very much\n\n- Rex Accavallo, CEO"},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '114731360778160310431',
#   'name': 'Katelynn Richardson',
#   'time': 1613759937139,
#   'rating': 5,
#   'text': 'Excellent customer service! I worked with a few people from Royal Group; initially Greg came and walked me through all of the options I had regarding a new alarm system, accessories, etc. He gave detailed descriptions of the equipment, and used his knowledge of the systems to give suggestions for what would work best in the space. I emailed with Rex about quotes and final decisions; he responded very quickly. Then, Matt came for installation, and walked me through how to log in and use the system we chose. The entire process was quick and effortless. Thank you!',
#   'pics': None,
#   'resp': {'time': 1613761142582,
#    'text': 'Kate - Wow, this is an awesome review - thank you so much for taking the time out of your day to leave us a review. You were a pleasure to work with and im so glad your experience has been positive with our team. Im even more excited for you guys to have a brand new system that your comfortable and happy with.\n\nShould any questions pop up, please reach out. Thank you so much for your business and local support.\n\nHave a great and relaxing weekend :-)'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '112552553578491305162',
#   'name': 'Vicki Baraiolo',
#   'time': 1614178105667,
#   'rating': 5,
#   'text': 'I had a very intricate frame that I wanted to cover in mirror, lots of angles and curves.  I called Tom at The Royal Group to see if it was something they could do for me.  I brought the mirror to their shop and Tom explained the process and confirmed that it could be done.  About a week later I got the call that it was completed.  I was thrilled with the results!!  The mirror is absolutely stunning, the workmanship is excellent and the service is beyond my expectations!  I highly recommend Royal Glass to anyone needing mirror or glass work.  They are the best!',
#   'pics': None,
#   'resp': {'time': 1614208816296,
#    'text': 'Evening Vicki. Wow, thanks so much for the amazing review! ⭐️😊 I’m so happy we could help bring the frame back to life and you were happy with the results!\n\nWe really appreciate your business and support. Come see us again if you need anything else.\n\nHave a nice and relaxing night.'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '114482739130934985758',
#   'name': 'Naomi Maglaris',
#   'time': 1615587308354,
#   'rating': 5,
#   'text': 'This system is so easy to use.  I love the email notifications informing us of who is opening and closing our business and what time it takes place. Also if anyone enters when we are closed.\nThe installation was professional and explained in detail. This company really wants their clients to be happy with their service and it shows!  I highly recommend!',
#   'pics': None,
#   'resp': {'time': 1615593945792,
#    'text': 'Naomi,\n\nThanks so much for the ⭐️‘s!!! I’m so happy that the new system is meeting all your expectations. I really appreciate your support, it was a real pleasure working with you 😊\n\nHave a great weekend and should any questions pop up, please reach out to me\n\n- Rex Accavallo'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '116100957553032365759',
#   'name': 'Peggy Stattel',
#   'time': 1623181758585,
#   'rating': 5,
#   'text': 'Agnes and Carolyn did a SPECTACULAR job putting new locks in our home.  Thank you, thank you, thank you!!!  Excellent work,',
#   'pics': None,
#   'resp': {'time': 1623183314301,
#    'text': 'Hi Peggy! Thank you so much for the nice review, im so pleased to hear that Agnes and Carolyn took care of everything you needed done today! They are both excellent\n\nThanks so much for your business and local support, we all truly appreciate it.\n\n- Rex Accavallo, CEO'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '114161992463071636907',
#   'name': 'Jennifer Sanford',
#   'time': 1613164140801,
#   'rating': 5,
#   'text': "Fantastic to work with! I needed to create a waiting space since COVID. George at Royal Glass helped me figure out how to make it so much better than I imagined. They even bent over backwards to fix a detail after I forgot to communicate how I envisioned it. So happy with Royal's!",
#   'pics': None,
#   'resp': {'time': 1613174314824,
#    'text': 'Good Evening, Jennifer! I love to hear that your so pleased with your new space and we could help with that. George is excellent, he has been part of our team for over (20) years. Please let us know if you need anything else at all or have any questions.\n\nWe really appreciate your support and keeping the business local! Have an excellent weekend and stay warm out there.\n\n- Rex Accavallo, CEO'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '115808109003221072646',
#   'name': 'Colin Comi',
#   'time': 1610366730833,
#   'rating': 5,
#   'text': 'We had an excellent experience with Rex and his team of professionals.  Our  security system installation was smooth and all of our questions were answered.  Based on this experience, we expanded our system to include smoke & CO protection.  Thanks again!  Colin & Keri (Colchester, VT)',
#   'pics': None,
#   'resp': {'time': 1610371685864,
#    'text': 'Thanks so much Colin. Matt and I really enjoyed working with you and Keri and hope to work together more in the future. We really appreciate the kind review, have a great week!\n\n- Rex Accavallo'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '109634488900995987445',
#   'name': 'Kevin Commins',
#   'time': 1599673683922,
#   'rating': 5,
#   'text': 'The Royal Group recently installed a fire alarm system at our home.  We were very pleased with the professionalism of both the company and the installer.  They answered all of our questions and installed the system within two weeks of first contacting them.  The installer made a point of not leaving until we were fully instructed on and comfortable with the system.   Best of all, unlike the hardware store smoke detectors we used to have, we know have somebody to call with any questions about servicing or maintenance.  Highly recommend.',
#   'pics': None,
#   'resp': {'time': 1599679724169,
#    'text': 'Kevin, Thank you so much for taking the time to write us such a kind review! I really enjoyed working with you on this and im glad the new system provides you with the peace of mind you guys were looking for. You know where to find us if you need anything at all!\n\nHave a great rest of the day, Kevin!\n\nRex'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '117514789685845745140',
#   'name': 'José Padilla',
#   'time': 1608292339670,
#   'rating': 5,
#   'text': 'Agnes was fantastic.  Knew exactly what locks would work best and keeps many new products on hand.   You won’t find a better locksmith in lower VT.',
#   'pics': None,
#   'resp': {'time': 1608299684952,
#    'text': "Morning, Jose! Thank you very much for taking time to leave us such a nice Google Review. Agnes is excellent! I'm so happy that you had a great experience. Please give us a shout in the future if there is anything else we can help you with.\n\nI hope you and your family have a nice and relaxing Holiday and New Years!"},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '104530912034852724955',
#   'name': 'Thomas Mills',
#   'time': 1598042645693,
#   'rating': 5,
#   'text': "The Royal Group's installed cameras with amazing detail and the ability to capture a small image: Exactly what I need to capture a clear image of a face. Rex came to the house and suggested a creative solution, and Austin did a great job with the installation. I am very happy with these cameras vs a Ring camera or similar. I have much greater depth of field and width with the cameras from Royal. Thank you Rex!",
#   'pics': None,
#   'resp': {'time': 1598043960339,
#    'text': "Hi Tom! Thanks so much for such an amazing review! We sincerely appreciate you taking the time from your day to do this. I'm very pleased to hear your loving the video quality with the new camera system.....should any questions arise, please let us know! Have a great weekend.\n\nRex Accavallo"},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '103483831247785956009',
#   'name': 'Jim deFau',
#   'time': 1604668759177,
#   'rating': 5,
#   'text': 'Love this team!  Purchased a home with outdated/old security system and this team came in evaluated, made recommendations, brought me up to code and feel safe and secure in my home. Outstanding to deal with and extremely reliable.',
#   'pics': None,
#   'resp': {'time': 1604671482019,
#    'text': 'Hi Jim! Wow, thanks so much! We really appreciate you taking the time to leave such a nice review. If there is anything else we can do, you know where to find us! Enjoy the weather out there :-)\n\n- Rex Accavallo'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '118228014676631598713',
#   'name': 'KPS',
#   'time': 1596220585806,
#   'rating': 5,
#   'text': "I worked with Joel to buy some equipment and the experience was just how it should be.  The communication at the beginning was clear and all questions were answered and clarified.  The purchase, delivery and installation was flawless.  Joel was great to work with and he made sure we were comfortable with our equipment.  I didn't really have much contact with the rest of the Royal Group, other than being directed to Joel and leaving messages that I know were passed on promptly.",
#   'pics': None,
#   'resp': {'time': 1596226257322,
#    'text': "Good Afternoon. Thanks so much for your Google Review! We appreciate you taking the time to do this for us. We really appreciate your business and I'm so glad to hear you were pleased with Joel's service, I will be sure to let him know. Have a great weekend!\n\nRex Accavallo\nCEO"},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '109127901803662731186',
#   'name': 'Gregor Kent',
#   'time': 1612460001416,
#   'rating': 5,
#   'text': 'Great team, great, efficient, friendly and accommodating service all around.  Royal Group really has their act together.  G.Kent  NBEP LLC',
#   'pics': None,
#   'resp': {'time': 1612464854684,
#    'text': 'Good Afternoon, Gregor! Thanks so much for the nice Google Review! I really appreciate you taking the time to do this for us. Its great to hear that your pleased with us and the service. Should you need anything at all moving forward, you know where to find us!\n\nHave a great rest of the week. Thank you again for the business and support!\n\n- Rex Accavallo'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '107856364355359567402',
#   'name': 'Sean SORRELL',
#   'time': 1592944755302,
#   'rating': 5,
#   'text': 'I am a general contractor who hired royal group to install a security system in a small commercial space for my client. Rex was very flexible and responsive to update the system that was needed and make sure the customer was happy with the proposed package. Matt, the installer for our project, carried himself with a professional and very knowledgeable attitude toward our project. He kept me well informed throughout the process and had an excellent attitude through the whole process.',
#   'pics': None,
#   'resp': {'time': 1592953259300,
#    'text': 'Sean, Thank you so much for taking time from your day to leave us such a nice review🙏 !  It was a please working with you on this project.....we really appreciate the business. I hope to work with you again on the next one. Have a great night!\n\nRex Accavallo'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '111829482769404070704',
#   'name': 'jennifer jean',
#   'time': 1591387213321,
#   'rating': 5,
#   'text': 'We arrived at our home and were unable to get in the main entrance, because our lock code unit on our door had dead batteries. We had two other doors to the house that we had never tried to use the keys to, and when we did they would not work. We were locked out. We called The Royal Group and they went over and above anything we could have expected, and were so wonderful in helping us! The tech arrived at our home quickly, and not only worked to successfully open the doors, she replaced the front doorknob, and made a duplicate key, so that we would have access to both our side and front doors with the same key. I cannot say enough how appreciative we are, of their quality work and responsiveness.',
#   'pics': None,
#   'resp': {'time': 1591391115200,
#    'text': "Jennifer, thank you very much for taking the time to leave such a nice review! I'm so happy we were able to assist you, I believe this was Agnes. She is excellent and has been with us for 37 Years! Again, thank you so much for the review and please reach out should you need anything else in the future. Have a wonderful weekend!"},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '118026874392842649478',
#   'name': 'rebecca kerns',
#   'time': 1620085852324,
#   'rating': 5,
#   'text': 'Always done right from wood stove to screens!',
#   'pics': None,
#   'resp': {'time': 1620087641504,
#    'text': 'Good Evening, Rebecca! Thanks SO much for the kind review. Quality workmanship has always been a top priority for us. Thank you again for your business and local support!\n\n- Rex Accavallo, CEO'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '101532740754036204131',
#   'name': 'Peter DeForge',
#   'time': 1580309946474,
#   'rating': 5,
#   'text': "A great company to work with.  Their sales and tech staff are very knowledgeable and easy to work with.  They will come up with a solution for any size company with any size budget.  Can't recommend them more highly!",
#   'pics': None,
#   'resp': {'time': 1580320228721,
#    'text': 'Good Afternoon, Peter - Really appreciate the review and kind words! It always means a lot when our clients take time out of their day to do this - thank you very much!! We look forward to working with you more in the future, have an awesome day'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '115404122636203550540',
#   'name': 'Chad Goulette',
#   'time': 1605195974445,
#   'rating': 5,
#   'text': 'Great place to do business with staff was great,thank u!',
#   'pics': None,
#   'resp': {'time': 1605195166792,
#    'text': 'Hi Chad!\n\nThank you so much for the 5-Star review. We really appreciate you keeping business local!\n\nHave a great rest of the week!\n\n- Rex Accavallo, CEO'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '113541882135291722680',
#   'name': 'Tweekedout11',
#   'time': 1592693052016,
#   'rating': 5,
#   'text': 'Had our lock jam at 11pm. Not knowing what to do I called Royal Glass. Agnes showed up within 20 minutes! She had the door open quickly, and my wife and I didn\'t need to sleep in the car. I would recommend Royal Glass\' service to anyone who needs it.\n\nA note for Royal Glass, your after hours message says "remain on the line if you are a current customer" this is not very welcoming when you offer 24 hour locksmithing services. I actually hung up the first time and almost didn\'t call back.',
#   'pics': None,
#   'resp': {'time': 1592746116305,
#    'text': 'Good Morning!\n\nThank you so much for leaving us this Google Review, we really appreciate it! Im so glad Agnes was able to respond quickly and resolve your issue :-)\n\nAs for the after hours message, I will look into this right away...I agree 100% that is not welcoming....Thank you for bringing it to my attention.\n\nHave a great Sunday, stay cool out there!'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '114722195307836576433',
#   'name': 'Hunter Seymour',
#   'time': 1591396667884,
#   'rating': 5,
#   'text': "Excellent service and a job well done. Joel took care of a tough to tackle job without an issue. There's a reason they have been in business over 80 years...",
#   'pics': None,
#   'resp': {'time': 1591400707807,
#    'text': 'Evening Hunter! Thanks so much for the kind review! That’s great to hear Joel was able to take care of everything you needed. Hope all is well, we really appreciate your business and hope to work more together in the future. Have a great weekend, and thank you again!'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '108630893973622591756',
#   'name': 'Scott Carroll',
#   'time': 1614171929148,
#   'rating': 5,
#   'text': 'Great to do business with...',
#   'pics': None,
#   'resp': {'time': 1614208323089,
#    'text': 'Thanks Scott! Appreciate the kind words 👍🏼\n\nWe really appreciate the business and support! Thanks for being a great customer!\n\nHave a nice evening!'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '107677103981372933691',
#   'name': 'Margaret Ganguly',
#   'time': 1576169317724,
#   'rating': 5,
#   'text': 'We had a camera install to our small nonprofit through The Royal Group. We worked with Peggy and Joel to get this done. The team was efficient, professional, and friendly; but above all provided beyond 5 star service. Thank you so much for the quality and timeliness-- it is hard to find these days!',
#   'pics': None,
#   'resp': {'time': 1576202116033,
#    'text': 'Good Evening, Margaret - I am so happy to hear of your experience! Peggy and Joel are both wonderful, thank you very much for your kind words! We look forward to working with you more in the future and Happy Holidays!!'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '104648300615436352102',
#   'name': 'Will Towne',
#   'time': 1587063425014,
#   'rating': 5,
#   'text': 'We have used The Royal Group for a number of years for our security needs. They are always timely, accommodating, and are clearly experts in their field. I would highly recommend them to anyone.',
#   'pics': None,
#   'resp': {'time': 1590074714972,
#    'text': 'Wow, thank you very much Will! We really appreciate this awesome review! Its always a please working with you. Stay well and enjoy the beautiful weather out there today! Look forward to connecting soon'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '104789336434407408181',
#   'name': 'Mark LaFountain',
#   'time': 1593005848256,
#   'rating': 5,
#   'text': 'Awesome Customer service, quick response, and willing to help whether you are a customer or not. A+ we need more businesses like this.',
#   'pics': None,
#   'resp': {'time': 1593376422014,
#    'text': 'Mark, thank you SO much! Really appreciate the kind words! Please reach out if you have any other questions or If I can assist with anything. Enjoy your Sunday!\n\nRex Accavallo'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '104189917427386471106',
#   'name': 'Ray Daigle',
#   'time': 1577127556093,
#   'rating': 5,
#   'text': 'Professional installation, Showed up as scheduled and cleaned up after they finished. Kept me in the loop as they progressed and alerted me to any issue as it came up. Highly recommend this company!',
#   'pics': None,
#   'resp': {'time': 1577133444246,
#    'text': 'Ray - Thanks so much for taking the time to write this review! We are so glad your loving the new system!! We look forward to working more in the future! Merry Christmas and Happy New Years from all of us at The Royal Group!'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '110529924242338089551',
#   'name': 'Larry Pitts',
#   'time': 1517656476816,
#   'rating': 5,
#   'text': "I didn't expect things to happen as fast as they did with Royal's glass team such as a custom made mirror with next day delivery and a shower door that fit perfectly in an out of plum opening. But, that certainly works for me being a contractor who has clients that want things done yesterday AND done right.\nThanks Royal group!!",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '108980665975608069965',
#   'name': 'Jeff R',
#   'time': 1582059996120,
#   'rating': 5,
#   'text': 'If you need a top quality job, by a group of professionals,  this is the only place to go! A plus service.',
#   'pics': None,
#   'resp': {'time': 1582063833737,
#    'text': 'Good Afternoon, Jeff\n\nThanks so much! We work very hard to have an extremely high level of quality. Really appreciate such a kind review and thank you very much for your business. Look forward to connecting more in the future, have a great night!'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '106145271540448245708',
#   'name': 'Chuck D',
#   'time': 1566329432018,
#   'rating': 1,
#   'text': 'I called over a week ago with an order for glass for 6 window panes and was told they would call when it was ready. Called today to check on it and they had not started it. I told them forget it I would go somewhere else where they actually take care of their customers. If they were too backed up or busy to complete the order in over 7 working days they should have said so at the start.',
#   'pics': None,
#   'resp': {'time': 1566404127060,
#    'text': "Chuck –\n\nThank you voicing your poor experience so that I am aware and can dig into why this happened.  If a timeline was not communicated to you when you dropped off your window panes, I sincerely apologize. I agree 100% that your experience is unacceptable and I am embarrassed with the sequence of events that occurred here. I do care deeply about each and every client, so please know that I don't take this lightly.\n\nI have spoken to the Glass Department manager about this and we are meeting to go over our systems in place in order to identify how this happened so that we can do our best to avoid it from happening again. Should you want to discuss further please feel free to call me anytime at (802).773.3313 or email me directly at rex@royalvt.com\n\nAgain, my sincere apologies Chuck. If you bring your window panes back in I will significantly discount the work given your experience and make sure they are done in a very timely manner. Please contact me if your willing to bring them back in.\n\nRespectfully,\n\nRex L. Accavallo, CSP\nCEO\nThe Royal Group, Inc.\nRutland Corporate Office (802).773.3313\nSouth Burlington Office (802).862.4112\nwww.theroyalgroupinc.com"},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '102722345114748541196',
#   'name': 'Karen Mckirryher',
#   'time': 1498683949116,
#   'rating': 5,
#   'text': 'The whole experience was great working with Royal Group.  I like having a local company as our provider so if we end up having any problems, they can physically come to our house to make it right; unlike an online company.  Royal Group has been around for many years and are a company your can trust.  Thank you to everyone!  No regrets here.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '115417116172514730442',
#   'name': 'Tim Puro',
#   'time': 1549919688918,
#   'rating': 5,
#   'text': 'These guys are the best.  They showed up right on time and did a fantastic job.  Thanks!',
#   'pics': None,
#   'resp': {'time': 1549977806013,
#    'text': 'Tim, thank you! We appreciate your business!'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '112907968101182526215',
#   'name': 'Kasia Dionne',
#   'time': 1550541650579,
#   'rating': 5,
#   'text': 'Great customer service, friendly and professional staff. I just had a new security system installed at my office - everything went well - from the initial consult, a detailed quote, installation and then a follow up to make sure things were running smoothly.',
#   'pics': None,
#   'resp': {'time': 1550586316035,
#    'text': "Kasia, thank you very much! It was a real pleasure working with you, and we're glad you're happy with your new system!"},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '114067210404939494577',
#   'name': 'Elaine Maynes',
#   'time': 1550243737384,
#   'rating': 5,
#   'text': 'From the initial sales consultation through the installation was a great experience.  Trevor was very helpful getting us the right system and Austin and Josh did a great job with the installation - very professional!',
#   'pics': None,
#   'resp': {'time': 1550244435327,
#    'text': 'Elaine, thank you very much! It was great working with you, and we really appreciate you being one of our customers!'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '114951944456393969622',
#   'name': 'Ann Eckler',
#   'time': 1549295081302,
#   'rating': 5,
#   'text': 'We use The Royal Group for our business and have always been pleased with their service!',
#   'pics': None,
#   'resp': {'time': 1549298029405,
#    'text': 'Ann, Thanks very much! We really appreciate having you as one of our clients!'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '103561690276041444062',
#   'name': 'Bill Ackerman',
#   'time': 1497302635910,
#   'rating': 5,
#   'text': 'I ordered a piece of double pane replacement glass from Royal Group in Rutland last Monday morning.  When I asked how long it would take they said usually under 10 working days. I thought that was reasonable. I got a call on Friday morning of the same week, saying the glass had arrived and I could pick it up anytime. Just 4 days was far beyond my expectations.  When I went in on Friday afternoon the gentleman at the counter was incredibly courteous (wish I had noticed his name) as was a gentleman "down back" who loaded me up and made sure it would travel well to \'get there in one piece\'. Glass shop humor - but good!  Even the price was lower than I expected! Thank you Royal Group. This was my first visit to Royal since I was formerly a countryside glass customer and had not yet discovered Royal,  I am really happy to know there is a great glass shop right here in Rutland that delivers the best customer service.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '114396096144379416780',
#   'name': 'Dave',
#   'time': 1535069233817,
#   'rating': 1,
#   'text': 'Needed a replacement window( frame damaged, glass broken). Tech measured wrong. Then I said I’ll drive up ( vac Ski home) the 5 1/2 HRs to be there, and make sure gets measured right. Then 3 weeks , later after going back/forth trying get window ordered, it was “ oh we can’t/won’t because afraid damage vinyl siding “Wait,??what? You were out 2x? It’s not an involved log home, brick, stone or going from one size to another. It’s a .... window! And you are .... wait for it .... a window company. So frustrating . Wasted 3 weeks, got nothing done. If I said I need 20 windows, would they not wanna touch a simple replacement job?it would’ve been “ we at your service !”.',
#   'pics': None,
#   'resp': {'time': 1535142336111,
#    'text': 'Good Afternoon Dave –\n\nFirst of all, I want to sincerely apologize for any poor experience you had with our Company. I spoke to the Glass Dept. Manager immediately once I saw this to understand what happened.\n\nWe did not measure your window correctly the first time – There was a miscommunication on our end and the on site Glazier only measured for the Glass. That was 100% our mistake and I do apologize for any inconvenience that caused you.\n\nThe following week we got back on site to re-measure the window. Regarding your travel time, I apologize you drove all the way up to Vermont; however, we never asked or required you to be on site as it was not needed.\n\nWe do certainly have ownership in any delays throughout this process. The summer is an extremely busy time for us with a lot of projects and we did have a large backlog and a few people out of the office on Vacation, sick etc during that time.\n\nLastly, addressing your window and the issue of replacing it. The problem is that the window is in a manufactured home and the nail fin for the window goes behind your vinyl siding. Due to this, It would entail removing all the siding around the window. The simple window replacement is not the issue; the siding is where the issue was. Our Glass Manager stressed this to you throughout your communications\n\nIn the end, we did not feel it was right to risk breaking your vinyl siding to replace the window.\n\nI do truly apologize that you were dissatisfied with this experience. As a local family owned and operated business that has been established since 1935, we always strive to do the right things in order to ensure all of our clients are 110% happy! We do our very best to do that with each and every project, regardless of the size or scope. We wish you the best of luck and hope to get a second chance in the future.\n\nRespectfully,\n\nRex L. Accavallo\nVice President'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '115466962376370431460',
#   'name': 'David Whitmore',
#   'time': 1532022517378,
#   'rating': 5,
#   'text': "Customer service beyond.  I was hoping that I could get a new handle for our sliding glass door that Royal had installed.  After initially speaking with Tom he did some research and called me back to say it didn't look promising.  It wasn't the end of the world and we could have lived with what we had.  Then without asking or calling,  Tom called to let me know that he did more digging and came up with a new handle.  That's customer service beyond.\nThank you,  David Whitmore",
#   'pics': None,
#   'resp': {'time': 1566404525102,
#    'text': 'David - I was going through our Google reviews and realized you did not receive a response and I apologize for that!\n\nThank you very much for taking the time to leave this kind and detailed review, very glad to hear you were pleased with Tom and our Glass Dept. - we truly appreciate it!\n\nIf anything is ever off, please always feel free to reach out to me (Rex Accavallo) the owner. Thanks again and have a wonderful rest of the week'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '116668786988494376196',
#   'name': 'Kim Webster',
#   'time': 1541685794773,
#   'rating': 5,
#   'text': 'Excellent customer service, very easy to work with. Tracey is great to deal with.',
#   'pics': None,
#   'resp': {'time': 1541690074021,
#    'text': 'Kim, Thank you so much for your kind review! Have a wonderful day!'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '107382525036596689455',
#   'name': 'Lily H',
#   'time': 1565098934073,
#   'rating': 5,
#   'text': 'Two royal group employees saved me! I ran out of gas on the side of the road and one of them stayed with my car and the other drive me to the nearest gas station and helped me get a gas can, fill it and took me back to my car, and made sure it started before they headed off!! Thank you Bob and Rustin!! Choose royal group, their employees care about more than what they are paid to do.',
#   'pics': None,
#   'resp': {'time': 1566405047470,
#    'text': 'Lily - Thank you SO much for your Google review!! We really appreciate it! Iam so happy we were able to help you out and get you back on the road safely.\n\nAgain, really appreciate the review and we were more than happy to help.\n\nHave an awesome rest of the week :-)'},
#   'gmap_id': '0x89e02445cb9db457:0x37f42bff4edf7a43'},
#  {'user_id': '108979378435066002945',
#   'name': 'Dash Porter',
#   'time': 1614877117437,
#   'rating': 5,
#   'text': "Quintessential Vermont experience (even for Vermonters)! We stayed overnight in the small cabin that Catherine and Mark host on Airbnb. It's extremely charming, clean, and stocked with everything you need for the wood cabin vibe, fireplace included of course. They have also marked several trails behind their home on which we enjoyed a relaxing walk at sunrise. Make sure to check out the hand crafted jewelry and small batch Maple Syrup as well!",
#   'pics': [{'url': ['https://lh5.googleusercontent.com/p/AF1QipN2FgUylviSESUI7AEx_sCdBonz-e_li2y0JdH4=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipMlBWSlcMKwj8T5XtataiY7rol5gQbS0zIT-rns=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipO5gZno_k9BNfIpUNCSSaQjs_Njnuv6cNJgpiql=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipNT5Urw6ERIlpZPwipr3V4lYAT4UjxzyMM6oTql=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipOFkiIAZMTbwo0gE-tsdpJRsTwPcnHTQJUtVS87=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipNAd24uQZqobfuxOXyepSg9KKFjqmcsewG6SAOT=w150-h150-k-no-p']}],
#   'resp': None,
#   'gmap_id': '0x4cb549e8877cf0d7:0xe8f003e6d73392ae'},
#  {'user_id': '101691529584625261355',
#   'name': 'Peter Henne',
#   'time': 1618783544463,
#   'rating': 5,
#   'text': "Great place. There's a cabin in the property to rent with a fire pit and screened in porch, and they sell maple syrup, eggs and flowers, with lots of good trails for hiking.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb549e8877cf0d7:0xe8f003e6d73392ae'},
#  {'user_id': '114786236578924601398',
#   'name': 'Kathleen Higgins',
#   'time': 1503775093088,
#   'rating': 5,
#   'text': 'Wonderful store. Pottery, creams and soaps, fun cards coasters and jewelry. A little bit of everything. Add it to your list of stops on scenic route 7 VT',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb54a301f3518f7:0x39af4eda1efb9117'},
#  {'user_id': '100344669220980408507',
#   'name': 'Jacquelyn Vero',
#   'time': 1366564616815,
#   'rating': 5,
#   'text': 'First time visit, and I will go back.   This shop has such unique gifts for everyone.  The buyer does an excellent job with their selections and I found just what I was looking for.\n\nNice friendly staff as well.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb54a301f3518f7:0x39af4eda1efb9117'},
#  {'user_id': '103647173039081882850',
#   'name': 'Lori Young',
#   'time': 1556986415414,
#   'rating': 5,
#   'text': 'Love Carrs....always have very nice people!!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb54a301f3518f7:0x39af4eda1efb9117'},
#  {'user_id': '115034704413086480336',
#   'name': 'cynceree reid',
#   'time': 1518927003135,
#   'rating': 4,
#   'text': "Love this flower shop. Every time I've been  there there helpful and friendly.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb54a301f3518f7:0x39af4eda1efb9117'},
#  {'user_id': '101013464086938229741',
#   'name': 'Wade C Davis',
#   'time': 1501460494111,
#   'rating': 5,
#   'text': 'Thrilled Brandon has such a high quality florist. Great local gifts, art, and knick-knacks, too.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb54a301f3518f7:0x39af4eda1efb9117'},
#  {'user_id': '108972441203222188332',
#   'name': 'Will Johnston',
#   'time': 1539897411544,
#   'rating': 5,
#   'text': 'Fun little place with a nice selection of gifts.',
#   'pics': None,
#   'resp': {'time': 1539902455739, 'text': 'Thank you very much!'},
#   'gmap_id': '0x4cb54a301f3518f7:0x39af4eda1efb9117'},
#  {'user_id': '107942392696477473068',
#   'name': 'Kyle Hutchins',
#   'time': 1497460914762,
#   'rating': 5,
#   'text': 'Friendly, helpful staff. Great place for gifts.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb54a301f3518f7:0x39af4eda1efb9117'},
#  {'user_id': '103134655243955314411',
#   'name': 'Angela Schrider',
#   'time': 1628737744108,
#   'rating': 5,
#   'text': "Very honest and helpful. Glad I went there. I won't be going anywhere else",
#   'pics': None,
#   'resp': {'time': 1628787266736,
#    'text': 'Wow, Angela, we love positive feedback! Thank you for sharing.'},
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '101856865551768948430',
#   'name': 'Henry Haefner',
#   'time': 1606162783440,
#   'rating': 1,
#   'text': 'I had them replace two broken studs on my right rear wheel, these had been cross threaded by another shop that remained unknown until I purchased new tires. The did repair the two broken studs but in doing so cross threaded two more. I discovered this just yesterday while swapping summer to snow tires. (I have separate wheels for the winter and summer). While removing the lug nuts from the right rear wheel two lugs were extremely difficult to remove such that I had to use a 4\' breaker bar to back the lugs off. The breaker bar was needed to completely remove the lug nuts. Two existing lugs were severely damaged due to cross threading. The shop states that is normal and occurs frequently. "We did not damage your lugs" was their response. The car is not old enough to suffer that kind of wear, they just will not admit to their mistake. Extremely disappointed in their service and negligence. See attached photos, beyond the seat of the lug nut the remaining section of the lugs are in good shape and did NOT wear out.',
#   'pics': [{'url': ['https://lh5.googleusercontent.com/p/AF1QipPQa7V_Ibv9GfDZQXPeNGV3W_dY-rRCJhTYieY9=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipOX0LxkfikC3U2TFyXJaOB308ZAmCpJ7D0PFMdj=w150-h150-k-no-p']}],
#   'resp': {'time': 1606226681412,
#    'text': 'Hi Henry our Customer Service Team would be happy to assist you. Please contact us at https://www.midas.com/aboutmidas/contactus/tabid/167/default.aspx'},
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '115449460612246432031',
#   'name': 'Joseph Tripodi',
#   'time': 1622852497743,
#   'rating': 5,
#   'text': 'Always friendly and helpful',
#   'pics': None,
#   'resp': {'time': 1623275389875,
#    'text': 'We were happy to help! Please let us know if we can do anything else in the future. Thank you for the great review!'},
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '103454899227943916340',
#   'name': 'tim cleary',
#   'time': 1581389602927,
#   'rating': 5,
#   'text': 'So focused on providing appropriate information for the repair. Providing options to choose to what extent you would like to execute repair. Less than dealership costs.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '109752195637290846463',
#   'name': 'Diana Lee',
#   'time': 1575320422408,
#   'rating': 5,
#   'text': 'Brent is very friendly and always willing to help me with my car needs. This place is trustworthy and conveniently located off Woodstock Ave in Rutland.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '114690950282772880919',
#   'name': 'Justin VonTiedemann',
#   'time': 1573831705797,
#   'rating': 5,
#   'text': 'Always friendly service. Honest and professional service handlers',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '108435896785327535952',
#   'name': 'John Quinn',
#   'time': 1454506476347,
#   'rating': 2,
#   'text': 'Had a coupon for an oil change and tire rotation. Made an appointment for 5:30 PM. Got there 10 min early and still had to wait until after 6 PM to get my vehicle in. After I left I noticed my "oil change life" indicator on my GM vehicle had not been re-set which is a nuisance as it\'s now showing I\'m past due for an oil change. Also I thought they would check the air pressure in my tires.....they did not and I found the pressures were way low on two of my tires. Not impressed with the experience.',
#   'pics': None,
#   'resp': {'time': 1454603629087,
#    'text': "Hi John, sorry to hear that you weren't happy with your oil change and tire service. We perform thousands of oil changes every year and strive to provide great service. We'd love to talk with you about what happened - please send us a message at social@midas.com."},
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '115837804704988124750',
#   'name': 'Jarrod Sammis',
#   'time': 1570481867232,
#   'rating': 1,
#   'text': "Have had multiple cars there and wouldn't even take a bike to have a tire changed there if I had to. If you want the work to be done incorrectly, get overcharged, and be insulted by the staff that work there because you call them out on their mistakes and halfassed work, this is your place.",
#   'pics': None,
#   'resp': {'time': 1570575204446,
#    'text': "Hi, we're committed to delivering great experiences, so we're disappointed  to see your one star review. We'd like to get the chance to talk to you more regarding this, but we need some more information from you first. Please click https://goo.gl/Htn9PP to tell us more about your visit. Thank you."},
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '106910255082950530879',
#   'name': 'Sean Lewis',
#   'time': 1555291401328,
#   'rating': 5,
#   'text': "These guys that work at this location are the best ever I take my truck to ford dealer with my engine light on they where telling me its 6 different problem when I know it's not so I take my truck to this midas location in rutland Vermont Woodstock ave they change only one sensor am my problem was solve thank you guys so much",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '105968068643577464566',
#   'name': 'Tee Gee',
#   'time': 1444512626559,
#   'rating': 5,
#   'text': 'Great service for over 20 years on both my foreign and domestic cars and trucks.. Prices are fair and friendly advice on needed repairs. Free WiFi too!',
#   'pics': None,
#   'resp': {'time': 1444407653896,
#    'text': 'Hi Tee Gee, thanks for sharing. We value your loyalty to our shop and are glad to hear you enjoy each service with us. We look forward to seeing you back in the shop for your next visit.'},
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '100798014023831660878',
#   'name': 'Zach Scarborough',
#   'time': 1517333697287,
#   'rating': 5,
#   'text': 'The environment is very professional and their work is top notch I go there every time I need work done',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '102846986425721735994',
#   'name': 'Eric Erwin',
#   'time': 1519941767787,
#   'rating': 5,
#   'text': "I'm not sure why people rate this place poorly. I've been using this place for many years, service has always been great. Honest and fair prices too. Let's face it, an auto repair these days cost much more than years ago thanks to evolving technology. So if you're expectations are to repair your car for $20, then it's time to buy a bike. I've brought my 2013 ford Taurus SHO, 2007 GMC Yukon, 2004 Cadillac escalade, 2009 ford flex, 2006 Cadillac CTS, suburban, and many other cars. Never once was I treated poorly or over sold on products. And a BIG plus is you can bring your own parts in and they'll install it! (No warranty of course). I recently had my Yukon in before going to DC with our 5 children and luggage. They fixed a knock sensor and looked over the overall condition to make sure it was road worthy, and I only paid about $250. This was a great deal considering the GMC dealer probably would have cost twice as much and wouldn't get me in for a week. Great job midas Rutland. For all those skeptical, just try it!",
#   'pics': None,
#   'resp': {'time': 1520009810716,
#    'text': 'Hi Eric, thanks for sharing! We appreciate your loyalty to our shop and are glad to hear you enjoy each service with us. We look forward to seeing you back in the shop for your next visit.'},
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '112633504159194034797',
#   'name': 'Mark Tittemore',
#   'time': 1577278014143,
#   'rating': 4,
#   'text': 'Gabriel does great work',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '100506431639216684869',
#   'name': 'James Kalb',
#   'time': 1561517306584,
#   'rating': 5,
#   'text': 'Although they weren’t able to do the work I needed, they were very kind through the process (and didn’t charge me for a consultation).',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '116899744317142760522',
#   'name': 'Paul Marshall',
#   'time': 1546972069810,
#   'rating': 5,
#   'text': "These guys are consummate professionals, friendly, great prices, and attention to detail. Don't go anywhere else, you won't be disappointed.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '113349631868742160668',
#   'name': 'Rock Strongo',
#   'time': 1582423983829,
#   'rating': 4,
#   'text': 'Good quality work.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e024446398691f:0x4011d3a0f8636036'},
#  {'user_id': '102422902652540141178',
#   'name': 'Reality Zone',
#   'time': 1550025611637,
#   'rating': 1,
#   'text': 'If you want to get ripped off, very dishonest all around. Brought car to 2nd opinion Midas billed over $1000.00 more',
#   'pics': None,
#   'resp': {'time': 1550176962645,
# ...
#  {'user_id': '111425373608881162514',
#   'name': 'Charles Putnam',
#   'time': 1543120655407,
#   'rating': 2,
#   'text': "Band was so painfully loud for such a small space.  So loud everything was muffled and couldn't even talk to person next to you",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e09663f2831197:0x9af0c6f17c2a1e74'},
#  {'user_id': '117380127925517774446',
#   'name': 'Brittany Warren',
#   'time': 1525236651698,
#   'rating': 5,
#   'text': 'Good band, Great drinks and great people.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e09663f2831197:0x9af0c6f17c2a1e74'},
#  {'user_id': '109633828901153578105',
#   'name': 'David Nguyen',
#   'time': 1487393039469,
#   'rating': 4,
#   'text': 'Just stopped in for a couple drinks and im not from the area nice lil bar if your nearby for the evening good atmosphere great spread of people diffrent types and gender ratio for those intrested',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e09663f2831197:0x9af0c6f17c2a1e74'},
#  {'user_id': '108615988475424268961',
#   'name': 'John Gillespie',
#   'time': 1508540504740,
#   'rating': 5,
#   'text': 'Had the fish sandwich.  Loved it.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e09663f2831197:0x9af0c6f17c2a1e74'},
#  {'user_id': '102149365707269126778',
#   'name': 'Aileen Hamerton',
#   'time': 1508681385924,
#   'rating': 4,
#   'text': 'Friendly bar! Amazing band!!!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e09663f2831197:0x9af0c6f17c2a1e74'},
#  {'user_id': '112464661657934716937',
#   'name': 'jamie Strohmaier',
#   'time': 1517595388007,
#   'rating': 5,
#   'text': 'Always,a good time',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e09663f2831197:0x9af0c6f17c2a1e74'},
#  {'user_id': '114570038927578816587',
#   'name': 'Jessica Tobin',
#   'time': 1542632481772,
#   'rating': 5,
#   'text': 'Great bar',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e09663f2831197:0x9af0c6f17c2a1e74'},
#  {'user_id': '109311581546387226715',
#   'name': 'Kenny “SEC8 Kenny” McCormick',
#   'time': 1541224887578,
#   'rating': 5,
#   'text': 'Great',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e09663f2831197:0x9af0c6f17c2a1e74'},
#  {'user_id': '109109613661944703767',
#   'name': 'Ryan Sweet',
#   'time': 1555599498682,
#   'rating': 5,
#   'text': 'Awesome',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e09663f2831197:0x9af0c6f17c2a1e74'},
#  {'user_id': '113250739456577874217',
#   'name': 'David LaPointe',
#   'time': 1496685142876,
#   'rating': 3,
#   'text': 'Too young for me',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e09663f2831197:0x9af0c6f17c2a1e74'},
#  {'user_id': '109914582434005874559',
#   'name': 'Ray Smith',
#   'time': 1561296889431,
#   'rating': 5,
#   'text': 'Good good...service thanks Al and Johnny\nVery nice. Folks....friendly',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca791d18585a5f:0x4d9e5c647b1f97d2'},
#  {'user_id': '115961351118062771236',
#   'name': 'Scott Boyson',
#   'time': 1629408335986,
#   'rating': 5,
#   'text': 'Mike does a great job! Funny to talk to!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca72e64d451c4f:0x5f951a908b5f907f'},
#  {'user_id': '104026839829016123767',
#   'name': 'Allen Ladue',
#   'time': 1624721454939,
#   'rating': 5,
#   'text': 'Great haircut.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca72e64d451c4f:0x5f951a908b5f907f'},
#  {'user_id': '114524826924653326823',
#   'name': 'Sandy FL',
#   'time': 1554941407326,
#   'rating': 5,
#   'text': 'My husband recently lost his regular barber, so decided to try this place in the town where we live.  His hair looks great!  He will definitely return!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca72e64d451c4f:0x5f951a908b5f907f'},
#  {'user_id': '100676823788914796098',
#   'name': 'M',
#   'time': 1605214378370,
#   'rating': 5,
#   'text': 'Outstanding as always!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca72e64d451c4f:0x5f951a908b5f907f'},
#  {'user_id': '113542857080553561263',
#   'name': 'Charles Borchers',
#   'time': 1553552318435,
#   'rating': 5,
#   'text': 'Michael does a great job I am regular customer.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca72e64d451c4f:0x5f951a908b5f907f'},
#  {'user_id': '103264282822577961783',
#   'name': 'Charlie Gilroy',
#   'time': 1537331088448,
#   'rating': 5,
#   'text': 'The best kind of barber',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca72e64d451c4f:0x5f951a908b5f907f'},
#  {'user_id': '112656295267919521571',
#   'name': 'Bill Marlette',
#   'time': 1553046285862,
#   'rating': 5,
#   'text': 'Excellent service.... always',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca72e64d451c4f:0x5f951a908b5f907f'},
#  {'user_id': '112336242099627574025',
#   'name': 'John Wilk',
#   'time': 1466987862902,
#   'rating': 5,
#   'text': 'Great local shop. Good conversation.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca72e64d451c4f:0x5f951a908b5f907f'},
#  {'user_id': '103511072263043805033',
#   'name': 'Ryguy Doe',
#   'time': 1324982346512,
#   'rating': 4,
#   'text': "It's a barber shop and Roger is a nice guy.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca72e64d451c4f:0x5f951a908b5f907f'},
#  {'user_id': '112492620658596680357',
#   'name': 'Brian Valentine',
#   'time': 1465610577267,
#   'rating': 5,
#   'text': 'Great haircut and local experience.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca72e64d451c4f:0x5f951a908b5f907f'},
#  {'user_id': '117835852287791371529',
#   'name': 'Kenneth Lane',
#   'time': 1501353538802,
#   'rating': 5,
#   'text': 'Good place,',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca72e64d451c4f:0x5f951a908b5f907f'},
#  {'user_id': '102247022700682446843',
#   'name': 'Mike Gibbons',
#   'time': 1625956805719,
#   'rating': 5,
#   'text': 'Amazing. Kudos to the purple who thought this up!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca7b26abee504f:0xdfd7f1bd260c83a7'},
#  {'user_id': '111267975626898189964',
#   'name': 'Joel Fichman',
#   'time': 1625085593458,
#   'rating': 5,
#   'text': 'Well worth the money.  Its a busy place.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca7b26abee504f:0xdfd7f1bd260c83a7'},
#  {'user_id': '110384183168484347068',
#   'name': 'Lisa Groeneveld',
#   'time': 1563219223128,
#   'rating': 5,
#   'text': "Wonderful place! But a little difficult to find. Currently there's some construction going on. Don't be deterred, just look for the signs (which are hard to see).  When you see St. John's club on left, turn right.",
#   'pics': [{'url': ['https://lh5.googleusercontent.com/p/AF1QipP4JV_eHLspRvzEieD8B1FNv5_5CSTqh4HEYp8w=w150-h150-k-no-p']}],
#   'resp': None,
#   'gmap_id': '0x4cca7b26abee504f:0xdfd7f1bd260c83a7'},
#  {'user_id': '104567028157630403957',
#   'name': 'Daniel',
#   'time': 1598813427500,
#   'rating': 5,
#   'text': 'Took a windsurfing class here.  Staff was amazing, super friendly.  Had a ton of fun on the water, and I will definitely be back for rentals.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cca7b26abee504f:0xdfd7f1bd260c83a7'},
#  {'user_id': '114655111256151074658',
#   'name': 'Mary Jane Simpson',
#   'time': 1498785325082,
#   'rating': 5,
#   'text': "I've had a great experience every time Tiama cuts my hair and shapes my brows.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb55d1ca7e91d03:0x139f0432022f2190'},
#  {'user_id': '108903536915275844228',
#   'name': 'Amy Rogers',
#   'time': 1606265580702,
#   'rating': 5,
#   'text': '(Translated by Google) Love Tiama !!!\n\n(Original)\nLove Tiama!!!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb55d1ca7e91d03:0x139f0432022f2190'},
#  {'user_id': '107474391628045266835',
#   'name': 'Matt Gould',
#   'time': 1601304381275,
#   'rating': 5,
#   'text': "The only dental office I've found that  I felt completely comfortable at.  Genuine, community minded people, and top notch work from Dr. Cimler",
#   'pics': None,
#   'resp': {'time': 1601585567094,
#    'text': 'We are so glad you feel this way!!  Glad to have you join the practice.'},
#   'gmap_id': '0x4cca9d87298a4d01:0x8ef9da417da8fb48'},
#  {'user_id': '117262889580362870682',
#   'name': 'John Stern',
#   'time': 1521648280177,
#   'rating': 5,
#   'text': 'Amazingly in-tune with the patient (my) needs! They are 45 minutes away, but I am more than happy to make the drive because of how good this office is.',
#   'pics': None,
#   'resp': {'time': 1521651057209,
#    'text': 'John, we are so glad you come!  Always nice catching up with you.  Melinda'},
#   'gmap_id': '0x4cca9d87298a4d01:0x8ef9da417da8fb48'},
#  {'user_id': '113850107486623548085',
#   'name': 'Edin Suljanovic',
#   'time': 1527783309106,
#   'rating': 5,
#   'text': 'To be honest I was a bit skeptical when Dr. Cimler replaced Dr. Maurer. However, Cimler’s skills and dentistry craftsmanship speaks for itself. He is excellent at his work and has a great staff that supports him. Melinda at the front desk is very detail oriented and friendly. In addition, she is very diligent with getting you in ASAP and on your schedule. I live in South Burlington and have been with Dr. Cimler for over 5 years now. Half of my family has switched to his office from both Middlebury and South Burlington locations.',
#   'pics': None,
#   'resp': {'time': 1527780950997,
#    'text': 'Edin this means so much to all of us!  Thank you so much for sharing your thoughts about our office.  So happy for you and your new family!'},
#   'gmap_id': '0x4cca9d87298a4d01:0x8ef9da417da8fb48'},
#  {'user_id': '109684737287992951686',
#   'name': 'Lois Wildasin',
#   'time': 1501614919499,
#   'rating': 5,
#   'text': 'Used to be afraid of getting shots. But this dentist. Dr cimler does the shots quick they are over before you know it.  And the others who work there are awsome also. I highly. Recommend. This crew 100%.   Lois wildasin',
#   'pics': None,
#   'resp': {'time': 1591643572548,
#    'text': 'Hi Lois, Glad you are not afraid any more! Thanks for the review!'},
#   'gmap_id': '0x4cca9d87298a4d01:0x8ef9da417da8fb48'},
#  {'user_id': '108602087847378225911',
#   'name': 'Jonathan Leo Connor',
#   'time': 1613101329600,
#   'rating': 5,
#   'text': 'I hired Chadwick for a traffic ticket. His team was very responsive to all my communications. The process was simple. I sent them an image of the ticket and filled out a couple forms and they took care of the rest. In the end, they got my ticket dismissed - no fine or points! Thank you!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e11a4fb95c36c1:0xc141229219630826'},
#  {'user_id': '108602087847378225911',
#   'name': 'Jonathan Leo Connor',
#   'time': 1610992640622,
#   'rating': 5,
#   'text': 'My car had a couple dents and a long scratch on it. I got quotes from two different body shops and this one was the cheapest. Not only that, but the actual cost ended up being even cheaper than the quote! And the best part: the work they did was beautiful! The car looks brand new again! Thank you, Hilltop!!!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb56779c96c8725:0xac1cd8fa1513e487'},
#  {'user_id': '108597878671545747157',
#   'name': 'Linda Zehnbauer',
#   'time': 1498741902674,
#   'rating': 4,
#   'text': 'Annual parade of cows in Brattleboro,VT. Celebrating and supporting our local farmers.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e105a9e8aff79d:0x89cb6edd78f9104c'},
#  {'user_id': '103590097645129503485',
#   'name': 'Christopher Warren',
#   'time': 1504839057279,
#   'rating': 5,
#   'text': 'Great, friendly spot to sit and relax while in town. Restrooms and Wi-fi, as well as interesting presentations',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e105a9e8aff79d:0x89cb6edd78f9104c'},
#  {'user_id': '108596878603902557399',
#   'name': 'Julie Phillips',
#   'time': 1570721049721,
#   'rating': 5,
#   'text': 'Wonderful place, well decorated for the Fall with pumpkin type people, flowers, pumpkins, gourds. Great hot apple cider donuts. Awesome 👍',
#   'pics': [{'url': ['https://lh5.googleusercontent.com/p/AF1QipO38esndpjR5PNAxGt5DrM-zW6Yfr__MApOZuLC=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipO0Efd62IDMHgeXrfWq1RyKEXBsWWvPMQ7tCxxr=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipMA3xqx2OX0wzuMQkwtowIsoSTkzJWYlMTHiRQc=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipN0exAYYlK34L2fmqNzVj2YtjU3q02yl_hE4tdA=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipPSapfgRh8dsrFghBiLmawomDX_1bv3YM93CIgA=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipMGoEd-gXWpvSInFSGInQ04ARn1y2rtpnXCmvR8=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipNJvyrx2eHDglTZ2DxB4rCPkB3VCPrRIVuvkSRm=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipPjcZ8twEpULLJhjH36x3dmCyRdYranUkfrtlQi=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipO53AhohiE2CiIKWP03QhEdveIU1hSW6U4mVUXH=w150-h150-k-no-p']},
#    {'url': ['https://lh5.googleusercontent.com/p/AF1QipOTWroV_dI4JsLKwgXNGsMZNkNUhPZwGh5sjT4R=w150-h150-k-no-p']}],
#   'resp': None,
#   'gmap_id': '0x89e08aaa13037547:0x1c5e27ee6e0d43ab'},
#  {'user_id': '114628918122042090348',
#   'name': 'C.M. Jones',
#   'time': 1602523766381,
#   'rating': 4,
#   'text': "Nice place overall very good selection of pumpkins gourds that sort of thing.the social distancing guidelines make it very confusing to walk through the property though we've been there plenty of times beforehand but the arrows kind of like almost get you lost.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e08aaa13037547:0x1c5e27ee6e0d43ab'},
#  {'user_id': '117394601328656085289',
#   'name': 'Jeffrey Hastings',
#   'time': 1567197762519,
#   'rating': 5,
#   'text': "A very gorgeous location in the fall with leaves. They have the best cider donuts I've ever tasted anywhere! Can't wait to go back and visit them again.",
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e08aaa13037547:0x1c5e27ee6e0d43ab'},
#  {'user_id': '115619855358547624929',
#   'name': 'Pam Gardner',
#   'time': 1475087699590,
#   'rating': 5,
#   'text': 'A beautiful working nursery went all out decorating for Halloween and fall. They invite you to take pictures outside with any of their colorful displays. The Green houses are full of beautiful plants, the garden center is full of unique items for your home and garden and they have a hut selling hot cider and donuts for the season. It is a fun place to visit.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x89e08aaa13037547:0x1c5e27ee6e0d43ab'},
#  {'user_id': '110210538808933235365',
#   'name': 'Deb Venman',
#   'time': 1603158950485,
#   'rating': 5,
#   'text': 'Since the start of the pandemic they have broadened their product line to include a wide range of fabric coronavirus masks, ranging from casually colorful patterns to conservative stripes and solids that can be matched with their ties and pocket squares.',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb55d850a8f7001:0xf919bd4c8e04a71b'},
#  {'user_id': '104980006719524025182',
#   'name': 'Kayla Hatch',
#   'time': 1518540950628,
#   'rating': 5,
#   'text': 'I love the different ties and bow ties they have',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb55d850a8f7001:0xf919bd4c8e04a71b'},
#  {'user_id': '107167462703267480997',
#   'name': 'Paula Rich',
#   'time': 1516963147729,
#   'rating': 5,
#   'text': 'I  work  here',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb55d850a8f7001:0xf919bd4c8e04a71b'},
#  {'user_id': '102369589002884454488',
#   'name': 'Matt Hill',
#   'time': 1603323576553,
#   'rating': 5,
#   'text': 'Nothing tops this place! Ever!',
#   'pics': None,
#   'resp': None,
#   'gmap_id': '0x4cb5eab4f2efe8ef:0x3f7bd8abeb943c3a'},
#  {'user_id': '108592658633286654166',
#   'name': 'Will Frank',
#   'time': 1508115704883,
#   'rating': 3,
#   'text': 'Hmmm...\nThe place was closed.',
#   'pics': None,
#   'resp': {'time': 1580519019919,
#    'text': "Sorry about that Will- we are only at the Creamery during production days. When we aren't making cheese, you can find our cheese at our markets or you can now order online at https://mtmansfieldcreamery.com"},
#   'gmap_id': '0x4cb5eab4f2efe8ef:0x3f7bd8abeb943c3a'},
#  ...]
